# %%
from model.table import Table

from model.holdem_round import HoldemRound
from players.floyd_folds import Floyd
from players.callie_calls import Callie
from players.robby_random import Robby
from players.ricky_raise import Ricky

# %%
players = [
    Ricky("Josh", 100),
    Callie("Madi", 100),
    Floyd("Cody", 100),
    Robby("Michelle", 100),
    Callie("Sophia", 100),
    Floyd("Beezie", 100)
]

round = HoldemRound(
    players=players,
    blind=1
)

# %%
players, table = round.play()
# Out:
# Collecting blinds
# Beezie is placing big blind: 2
# Beezie placed big blind: 96 left in bankroll
# Sophia is placing small blind: 1
# Sophia placed small blind: 98 left in bankroll
# delt Josh to Card("8", "Clubs")
# delt Madi to Card("2", "Hearts")
# delt Cody to Card("A", "Hearts")
# delt Michelle to Card("6", "Clubs")
# delt Sophia to Card("J", "Clubs")
# delt Beezie to Card("8", "Diamonds")
# delt Josh to Card("Q", "Clubs")
# delt Madi to Card("5", "Hearts")
# delt Cody to Card("4", "Diamonds")
# delt Michelle to Card("9", "Diamonds")
# delt Sophia to Card("6", "Hearts")
# delt Beezie to Card("9", "Clubs")
# Starting betting round
# The bet is 2 to Madi
# Play - Madi: CALL
# Got action: Action(CALL, 2)
# handling action: Action(CALL, 2)
# Processing Action - Madi: CALL
# Madi: 100
# Action amount: 2
# Money on table: 0
# Cash into pot: 2
# Madi calling, raising, or matching by 2
# Madi still has: 98 in their bankroll
# The bet is 2 to Cody
# Play - Cody: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Cody: FOLD
# Cody: 100
# Cody: FOLD
# Cody is folding: 100
# Cody folds
# The bet is 2 to Michelle
# Play - Michelle: CALL
# Got action: Action(CALL, 2)
# handling action: Action(CALL, 2)
# Processing Action - Michelle: CALL
# Michelle: 100
# Action amount: 2
# Money on table: 0
# Cash into pot: 2
# Michelle calling, raising, or matching by 2
# Michelle still has: 98 in their bankroll
# The bet is 2 to Sophia
# Play - Sophia: CALL
# Got action: Action(CALL, 2)
# handling action: Action(CALL, 2)
# Processing Action - Sophia: CALL
# Sophia: 98
# Action amount: 2
# Money on table: 1
# Cash into pot: 1
# Sophia calling, raising, or matching by 2
# Sophia still has: 97 in their bankroll
# The bet is 2 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 96
# Beezie: FOLD
# Beezie is folding: 96
# Beezie folds
# The bet is 2 to Josh
# Play - Josh: RAISE
# Got action: Action(RAISE, 18)
# handling action: Action(RAISE, 18)
# Processing Action - Josh: RAISE
# Josh: 100
# Action amount: 18
# Money on table: 0
# Cash into pot: 18
# Josh calling, raising, or matching by 18
# Josh still has: 82 in their bankroll
# Josh raises
# The bet is 18 to Madi
# Play - Madi: CALL
# Got action: Action(CALL, 18)
# handling action: Action(CALL, 18)
# Processing Action - Madi: CALL
# Madi: 98
# Action amount: 18
# Money on table: 2
# Cash into pot: 16
# Madi calling, raising, or matching by 18
# Madi still has: 82 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Josh', 'Madi', 'Michelle', 'Sophia']
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Michelle
# Called - Active Player: Michelle
# Play - Michelle: FOLD
# handling action: Action(FOLD, None)
# Processing Action - Michelle: FOLD
# Michelle: 98
# Michelle: FOLD
# Michelle is folding: 98
# Michelle folds
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Play - Sophia: CALL
# handling action: Action(CALL, 18)
# Processing Action - Sophia: CALL
# Sophia: 97
# Action amount: 18
# Money on table: 2
# Cash into pot: 16
# Sophia calling, raising, or matching by 18
# Sophia still has: 81 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Josh
# Called - Active Player: Josh
# Play - Josh: MATCH
# handling action: Action(MATCH, 18)
# Processing Action - Josh: MATCH
# Josh: 82
# Action amount: 18
# Money on table: 18
# Cash into pot: 0
# Josh calling, raising, or matching by 18
# Josh still has: 82 in their bankroll
# Betting round is complete
# Players still in: ['Josh', 'Madi', 'Sophia']
# Starting betting round
# The bet is 18 to Madi
# Play - Madi: CALL
# Got action: Action(CALL, 18)
# handling action: Action(CALL, 18)
# Processing Action - Madi: CALL
# Madi: 82
# Action amount: 18
# Money on table: 18
# Cash into pot: 0
# Madi calling, raising, or matching by 18
# Madi still has: 82 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Josh', 'Madi', 'Sophia']
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Play - Sophia: CALL
# handling action: Action(CALL, 18)
# Processing Action - Sophia: CALL
# Sophia: 81
# Action amount: 18
# Money on table: 18
# Cash into pot: 0
# Sophia calling, raising, or matching by 18
# Sophia still has: 81 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Josh
# Called - Active Player: Josh
# Play - Josh: MATCH
# handling action: Action(MATCH, 18)
# Processing Action - Josh: MATCH
# Josh: 82
# Action amount: 18
# Money on table: 18
# Cash into pot: 0
# Josh calling, raising, or matching by 18
# Josh still has: 82 in their bankroll
# Betting round is complete
# Players still in: ['Josh', 'Madi', 'Sophia']
# Starting betting round
# The bet is 18 to Madi
# Play - Madi: CALL
# Got action: Action(CALL, 18)
# handling action: Action(CALL, 18)
# Processing Action - Madi: CALL
# Madi: 82
# Action amount: 18
# Money on table: 18
# Cash into pot: 0
# Madi calling, raising, or matching by 18
# Madi still has: 82 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Josh', 'Madi', 'Sophia']
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Play - Sophia: CALL
# handling action: Action(CALL, 18)
# Processing Action - Sophia: CALL
# Sophia: 81
# Action amount: 18
# Money on table: 18
# Cash into pot: 0
# Sophia calling, raising, or matching by 18
# Sophia still has: 81 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Josh
# Called - Active Player: Josh
# Play - Josh: MATCH
# handling action: Action(MATCH, 18)
# Processing Action - Josh: MATCH
# Josh: 82
# Action amount: 18
# Money on table: 18
# Cash into pot: 0
# Josh calling, raising, or matching by 18
# Josh still has: 82 in their bankroll
# Betting round is complete
# Players still in: ['Josh', 'Madi', 'Sophia']
# Starting betting round
# The bet is 18 to Madi
# Play - Madi: CALL
# Got action: Action(CALL, 18)
# handling action: Action(CALL, 18)
# Processing Action - Madi: CALL
# Madi: 82
# Action amount: 18
# Money on table: 18
# Cash into pot: 0
# Madi calling, raising, or matching by 18
# Madi still has: 82 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Josh', 'Madi', 'Sophia']
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Play - Sophia: CALL
# handling action: Action(CALL, 18)
# Processing Action - Sophia: CALL
# Sophia: 81
# Action amount: 18
# Money on table: 18
# Cash into pot: 0
# Sophia calling, raising, or matching by 18
# Sophia still has: 81 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Josh
# Called - Active Player: Josh
# Play - Josh: MATCH
# handling action: Action(MATCH, 18)
# Processing Action - Josh: MATCH
# Josh: 82
# Action amount: 18
# Money on table: 18
# Cash into pot: 0
# Josh calling, raising, or matching by 18
# Josh still has: 82 in their bankroll
# Betting round is complete
# Players still in: ['Josh', 'Madi', 'Sophia']
# Josh is holding [Card("8", "Clubs"), Card("Q", "Clubs")]
# Josh makes a hand from: [Card("8", "Clubs"), Card("Q", "Clubs"), Card("8", "Clubs"), Card("Q", "Clubs"), Card("10", "Hearts"), Card("K", "Diamonds"), Card("7", "Spades"), Card("K", "Hearts"), Card("5", "Spades")]
# Josh presents hand: QC, QC, 10H, KD, KH
# Madi is holding [Card("2", "Hearts"), Card("5", "Hearts")]
# Madi makes a hand from: [Card("2", "Hearts"), Card("5", "Hearts"), Card("2", "Hearts"), Card("5", "Hearts"), Card("10", "Hearts"), Card("K", "Diamonds"), Card("7", "Spades"), Card("K", "Hearts"), Card("5", "Spades")]
# Madi presents hand: 5H, 5H, KD, KH, 5S
# Sophia is holding [Card("J", "Clubs"), Card("6", "Hearts")]
# Sophia makes a hand from: [Card("J", "Clubs"), Card("6", "Hearts"), Card("J", "Clubs"), Card("6", "Hearts"), Card("10", "Hearts"), Card("K", "Diamonds"), Card("7", "Spades"), Card("K", "Hearts"), Card("5", "Spades")]
# Sophia presents hand: JC, JC, 10H, KD, KH
# Josh is holding [Card("8", "Clubs"), Card("Q", "Clubs"), Card("8", "Clubs"), Card("Q", "Clubs"), Card("10", "Hearts"), Card("K", "Diamonds"), Card("7", "Spades"), Card("K", "Hearts"), Card("5", "Spades")]
# Josh presents hand: QC, QC, 10H, KD, KH
# Madi is holding [Card("2", "Hearts"), Card("5", "Hearts"), Card("2", "Hearts"), Card("5", "Hearts"), Card("10", "Hearts"), Card("K", "Diamonds"), Card("7", "Spades"), Card("K", "Hearts"), Card("5", "Spades")]
# Madi presents hand: 5H, 5H, KD, KH, 5S
# Sophia is holding [Card("J", "Clubs"), Card("6", "Hearts"), Card("J", "Clubs"), Card("6", "Hearts"), Card("10", "Hearts"), Card("K", "Diamonds"), Card("7", "Spades"), Card("K", "Hearts"), Card("5", "Spades")]
# Sophia presents hand: JC, JC, 10H, KD, KH
# Winning Hand: 5H, 5H, KD, KH, 5S
# ('FULL_HOUSE', '5', 'K'): 5H, 5H, KD, KH, 5S
# ['Madi']
# Flop: [Card("10", "Hearts"), Card("K", "Diamonds"), Card("7", "Spades")]
# Turn: Card("K", "Hearts")
# River: Card("5", "Spades")
# Madi collects a $58.0 pot

# %%
round.players[0]
# Out:
# Player(Josh, 82)

# %%
round.players[1]
# Out:
# Player(Madi, 140.0)

# %%
round.players[2]
# Out:
# Player(Cody, 100)

# %%
round.players[3]
# Out:
# Player(Michelle, 98)

# %%
round.players[4]
# Out:
# Player(Sophia, 81)

# %%
round.players[5]
# Out:
# Player(Beezie, 96)

# %%
round_2 = HoldemRound(
    players=players,
    table=table
)

# %%
players, table = round_2.play()
# Out:
# Collecting blinds
# Josh is placing big blind: 2
# Josh placed big blind: 37 left in bankroll
# Beezie is placing small blind: 1
# Beezie placed small blind: 92 left in bankroll
# delt Josh to Card("3", "Diamonds")
# delt Madi to Card("9", "Clubs")
# delt Cody to Card("8", "Diamonds")
# delt Michelle to Card("5", "Hearts")
# delt Sophia to Card("5", "Diamonds")
# delt Beezie to Card("9", "Spades")
# delt Josh to Card("6", "Spades")
# delt Madi to Card("4", "Diamonds")
# delt Cody to Card("2", "Clubs")
# delt Michelle to Card("9", "Diamonds")
# delt Sophia to Card("10", "Clubs")
# delt Beezie to Card("3", "Hearts")
# Starting betting round
# The bet is 39 to Madi
# Play - Madi: CALL
# Got action: Action(CALL, 39)
# handling action: Action(CALL, 39)
# Processing Action - Madi: CALL
# Madi: 101.0
# Action amount: 39
# Money on table: 0
# Cash into pot: 39
# Madi calling, raising, or matching by 39
# Madi still has: 62.0 in their bankroll
# The bet is 39 to Cody
# Play - Cody: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Cody: FOLD
# Cody: 100
# Cody: FOLD
# Cody is folding: 100
# Cody folds
# The bet is 39 to Michelle
# Play - Michelle: CALL
# Got action: Action(CALL, 39)
# handling action: Action(CALL, 39)
# Processing Action - Michelle: CALL
# Michelle: 216.0
# Action amount: 39
# Money on table: 0
# Cash into pot: 39
# Michelle calling, raising, or matching by 39
# Michelle still has: 177.0 in their bankroll
# The bet is 39 to Sophia
# Play - Sophia: CALL
# Got action: Action(CALL, 39)
# handling action: Action(CALL, 39)
# Processing Action - Sophia: CALL
# Sophia: 42
# Action amount: 39
# Money on table: 0
# Cash into pot: 39
# Sophia calling, raising, or matching by 39
# Sophia still has: 3 in their bankroll
# The bet is 39 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 92
# Beezie: FOLD
# Beezie is folding: 92
# Beezie folds
# The bet is 39 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 37
# Josh: FOLD
# Josh is folding: 37
# Josh folds
# The bet is 39 to Madi
# Play - Madi: CALL
# Got action: Action(CALL, 39)
# handling action: Action(CALL, 39)
# Processing Action - Madi: CALL
# Madi: 62.0
# Action amount: 39
# Money on table: 39
# Cash into pot: 0
# Madi calling, raising, or matching by 39
# Madi still has: 62.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Michelle', 'Sophia']
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Michelle
# Called - Active Player: Michelle
# Play - Michelle: FOLD
# handling action: Action(FOLD, None)
# Processing Action - Michelle: FOLD
# Michelle: 177.0
# Michelle: FOLD
# Michelle is folding: 177.0
# Michelle folds
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Play - Sophia: CALL
# handling action: Action(CALL, 39)
# Processing Action - Sophia: CALL
# Sophia: 3
# Action amount: 39
# Money on table: 39
# Cash into pot: 0
# Sophia calling, raising, or matching by 39
# Sophia still has: 3 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Josh
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 39 to Madi
# Play - Madi: CALL
# Got action: Action(CALL, 39)
# handling action: Action(CALL, 39)
# Processing Action - Madi: CALL
# Madi: 62.0
# Action amount: 39
# Money on table: 39
# Cash into pot: 0
# Madi calling, raising, or matching by 39
# Madi still has: 62.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Play - Sophia: CALL
# handling action: Action(CALL, 39)
# Processing Action - Sophia: CALL
# Sophia: 3
# Action amount: 39
# Money on table: 39
# Cash into pot: 0
# Sophia calling, raising, or matching by 39
# Sophia still has: 3 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Josh
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 39 to Madi
# Play - Madi: CALL
# Got action: Action(CALL, 39)
# handling action: Action(CALL, 39)
# Processing Action - Madi: CALL
# Madi: 62.0
# Action amount: 39
# Money on table: 39
# Cash into pot: 0
# Madi calling, raising, or matching by 39
# Madi still has: 62.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Play - Sophia: CALL
# handling action: Action(CALL, 39)
# Processing Action - Sophia: CALL
# Sophia: 3
# Action amount: 39
# Money on table: 39
# Cash into pot: 0
# Sophia calling, raising, or matching by 39
# Sophia still has: 3 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Josh
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 39 to Madi
# Play - Madi: CALL
# Got action: Action(CALL, 39)
# handling action: Action(CALL, 39)
# Processing Action - Madi: CALL
# Madi: 62.0
# Action amount: 39
# Money on table: 39
# Cash into pot: 0
# Madi calling, raising, or matching by 39
# Madi still has: 62.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Play - Sophia: CALL
# handling action: Action(CALL, 39)
# Processing Action - Sophia: CALL
# Sophia: 3
# Action amount: 39
# Money on table: 39
# Cash into pot: 0
# Sophia calling, raising, or matching by 39
# Sophia still has: 3 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Josh
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("9", "Clubs"), Card("4", "Diamonds")]
# Madi makes a hand from: [Card("9", "Clubs"), Card("4", "Diamonds"), Card("9", "Clubs"), Card("4", "Diamonds"), Card("J", "Clubs"), Card("7", "Hearts"), Card("J", "Spades"), Card("A", "Diamonds"), Card("2", "Spades")]
# Madi presents hand: 9C, 9C, JC, JS, AD
# Sophia is holding [Card("5", "Diamonds"), Card("10", "Clubs")]
# Sophia makes a hand from: [Card("5", "Diamonds"), Card("10", "Clubs"), Card("5", "Diamonds"), Card("10", "Clubs"), Card("J", "Clubs"), Card("7", "Hearts"), Card("J", "Spades"), Card("A", "Diamonds"), Card("2", "Spades")]
# Sophia presents hand: 5D, 5D, JC, JS, AD
# Madi is holding [Card("9", "Clubs"), Card("4", "Diamonds"), Card("9", "Clubs"), Card("4", "Diamonds"), Card("J", "Clubs"), Card("7", "Hearts"), Card("J", "Spades"), Card("A", "Diamonds"), Card("2", "Spades")]
# Madi presents hand: 9C, 9C, JC, JS, AD
# Sophia is holding [Card("5", "Diamonds"), Card("10", "Clubs"), Card("5", "Diamonds"), Card("10", "Clubs"), Card("J", "Clubs"), Card("7", "Hearts"), Card("J", "Spades"), Card("A", "Diamonds"), Card("2", "Spades")]
# Sophia presents hand: 5D, 5D, JC, JS, AD
# Winning Hand: 9C, 9C, JC, JS, AD
# ('TWO_PAIR', ['9', 'J']): 9C, 9C, JC, JS, AD
# ['Madi']
# Flop: [Card("J", "Clubs"), Card("7", "Hearts"), Card("J", "Spades")]
# Turn: Card("A", "Diamonds")
# River: Card("2", "Spades")
# Madi collects a $277.0 pot

# %%
round_3 = HoldemRound(
    players=players,
    table=table
)

# %%
players, table = round_3.play()
# Out:
# Collecting blinds
# Madi is placing big blind: 2
# Madi placed big blind: 335.0 left in bankroll
# Josh is placing small blind: 1
# Josh placed small blind: 35 left in bankroll
# delt Josh to Card("7", "Spades")
# delt Madi to Card("2", "Hearts")
# delt Cody to Card("J", "Spades")
# delt Michelle to Card("Q", "Clubs")
# delt Sophia to Card("A", "Diamonds")
# delt Beezie to Card("3", "Clubs")
# delt Josh to Card("9", "Diamonds")
# delt Madi to Card("2", "Diamonds")
# delt Cody to Card("6", "Spades")
# delt Michelle to Card("10", "Diamonds")
# delt Sophia to Card("8", "Spades")
# delt Beezie to Card("8", "Diamonds")
# Starting betting round
# The bet is 39 to Michelle
# Play - Michelle: CALL
# Got action: Action(CALL, 39)
# handling action: Action(CALL, 39)
# Processing Action - Michelle: CALL
# Michelle: 177.0
# Action amount: 39
# Money on table: 0
# Cash into pot: 39
# Michelle calling, raising, or matching by 39
# Michelle still has: 138.0 in their bankroll
# The bet is 39 to Sophia
# Play - Sophia: CALL
# Got action: Action(CALL, 3)
# handling action: Action(CALL, 3)
# Processing Action - Sophia: CALL
# Sophia: 3
# Action amount: 3
# Money on table: 0
# Cash into pot: 3
# Sophia calling, raising, or matching by 3
# Sophia still has: 0 in their bankroll
# Splitting pot - Sophia is all in
# Players: ['Josh', 'Madi', 'Cody', 'Michelle', 'Sophia', 'Beezie']
# The bet is 39 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 92
# Beezie: FOLD
# Beezie is folding: 92
# Beezie folds
# The bet is 39 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 35
# Josh: FOLD
# Josh is folding: 35
# Josh folds
# The bet is 39 to Madi
# Play - Madi: CALL
# Got action: Action(CALL, 39)
# handling action: Action(CALL, 39)
# Processing Action - Madi: CALL
# Madi: 335.0
# Action amount: 39
# Money on table: 2
# Cash into pot: 37
# Madi calling, raising, or matching by 39
# Madi still has: 298.0 in their bankroll
# The bet is 39 to Cody
# Play - Cody: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Cody: FOLD
# Cody: 100
# Cody: FOLD
# Cody is folding: 100
# Cody folds
# The bet is 39 to Michelle
# Play - Michelle: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Michelle: FOLD
# Michelle: 138.0
# Michelle: FOLD
# Michelle is folding: 138.0
# Michelle folds
# The bet is 39 to Sophia
# Play - Sophia: CALL
# Got action: Action(CALL, 3)
# handling action: Action(CALL, 3)
# Processing Action - Sophia: CALL
# Sophia: 0
# Action amount: 3
# Money on table: 3
# Cash into pot: 0
# Sophia calling, raising, or matching by 3
# Sophia still has: 0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Splitting pot - Sophia is all in
# Players: ['Madi', 'Sophia']
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Play - Madi: CALL
# handling action: Action(CALL, 39)
# Processing Action - Madi: CALL
# Madi: 298.0
# Action amount: 39
# Money on table: 39
# Cash into pot: 0
# Madi calling, raising, or matching by 39
# Madi still has: 298.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Michelle
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 39 to Sophia
# Play - Sophia: CALL
# Got action: Action(CALL, 3)
# handling action: Action(CALL, 3)
# Processing Action - Sophia: CALL
# Sophia: 0
# Action amount: 3
# Money on table: 3
# Cash into pot: 0
# Sophia calling, raising, or matching by 3
# Sophia still has: 0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Splitting pot - Sophia is all in
# Players: ['Madi', 'Sophia']
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Play - Madi: CALL
# handling action: Action(CALL, 39)
# Processing Action - Madi: CALL
# Madi: 298.0
# Action amount: 39
# Money on table: 39
# Cash into pot: 0
# Madi calling, raising, or matching by 39
# Madi still has: 298.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Michelle
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 39 to Sophia
# Play - Sophia: CALL
# Got action: Action(CALL, 3)
# handling action: Action(CALL, 3)
# Processing Action - Sophia: CALL
# Sophia: 0
# Action amount: 3
# Money on table: 3
# Cash into pot: 0
# Sophia calling, raising, or matching by 3
# Sophia still has: 0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Splitting pot - Sophia is all in
# Players: ['Madi', 'Sophia']
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Play - Madi: CALL
# handling action: Action(CALL, 39)
# Processing Action - Madi: CALL
# Madi: 298.0
# Action amount: 39
# Money on table: 39
# Cash into pot: 0
# Madi calling, raising, or matching by 39
# Madi still has: 298.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Michelle
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 39 to Sophia
# Play - Sophia: CALL
# Got action: Action(CALL, 3)
# handling action: Action(CALL, 3)
# Processing Action - Sophia: CALL
# Sophia: 0
# Action amount: 3
# Money on table: 3
# Cash into pot: 0
# Sophia calling, raising, or matching by 3
# Sophia still has: 0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Splitting pot - Sophia is all in
# Players: ['Madi', 'Sophia']
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Play - Madi: CALL
# handling action: Action(CALL, 39)
# Processing Action - Madi: CALL
# Madi: 298.0
# Action amount: 39
# Money on table: 39
# Cash into pot: 0
# Madi calling, raising, or matching by 39
# Madi still has: 298.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Michelle
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("2", "Hearts"), Card("2", "Diamonds")]
# Madi makes a hand from: [Card("2", "Hearts"), Card("2", "Diamonds"), Card("2", "Hearts"), Card("2", "Diamonds"), Card("5", "Diamonds"), Card("7", "Clubs"), Card("3", "Diamonds"), Card("A", "Spades"), Card("K", "Hearts")]
# Madi presents hand: 2H, 2D, 2H, 2D, AS
# Sophia is holding [Card("A", "Diamonds"), Card("8", "Spades")]
# Sophia makes a hand from: [Card("A", "Diamonds"), Card("8", "Spades"), Card("A", "Diamonds"), Card("8", "Spades"), Card("5", "Diamonds"), Card("7", "Clubs"), Card("3", "Diamonds"), Card("A", "Spades"), Card("K", "Hearts")]
# Sophia presents hand: AD, 8S, AD, 8S, AS
# Madi is holding [Card("2", "Hearts"), Card("2", "Diamonds"), Card("2", "Hearts"), Card("2", "Diamonds"), Card("5", "Diamonds"), Card("7", "Clubs"), Card("3", "Diamonds"), Card("A", "Spades"), Card("K", "Hearts")]
# Madi presents hand: 2H, 2D, 2H, 2D, AS
# Sophia is holding [Card("A", "Diamonds"), Card("8", "Spades"), Card("A", "Diamonds"), Card("8", "Spades"), Card("5", "Diamonds"), Card("7", "Clubs"), Card("3", "Diamonds"), Card("A", "Spades"), Card("K", "Hearts")]
# Sophia presents hand: AD, 8S, AD, 8S, AS
# Winning Hand: 2H, 2D, 2H, 2D, AS
# ('FOUR_OF_A_KIND', '2'): 2H, 2D, 2H, 2D, AS
# ['Madi']
# Flop: [Card("5", "Diamonds"), Card("7", "Clubs"), Card("3", "Diamonds")]
# Turn: Card("A", "Spades")
# River: Card("K", "Hearts")
# Madi collects a $82.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 35)
# Player(Madi, 380.0)
# Player(Cody, 100)
# Player(Michelle, 138.0)
# Player(Sophia, 0)
# Player(Beezie, 92)

# %%
HoldemRound(
    players=players,
    table=table
).play()
# Out:
# Collecting blinds
# Cody is placing big blind: 2
# Cody placed big blind: 96 left in bankroll
# Madi is placing small blind: 1
# Madi placed small blind: 378.0 left in bankroll
# delt Josh to Card("10", "Clubs")
# delt Madi to Card("8", "Clubs")
# delt Cody to Card("8", "Spades")
# delt Michelle to Card("9", "Hearts")
# delt Sophia to Card("7", "Spades")
# delt Beezie to Card("J", "Clubs")
# delt Josh to Card("Q", "Clubs")
# delt Madi to Card("Q", "Hearts")
# delt Cody to Card("9", "Clubs")
# delt Michelle to Card("5", "Spades")
# delt Sophia to Card("2", "Spades")
# delt Beezie to Card("A", "Diamonds")
# Starting betting round
# The bet is 39 to Sophia
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/jq/w80pdyz11zbbhbvz7p8795gh0000gn/T/ipykernel_38360/719923906.py in <module>
# ----> 1 HoldemRound(
#       2     players=players,
#       3     table=table
#       4 ).play()
#
# ~/dev/cards/src/model/holdem_round.py in play(self)
#     260         self.collect_blinds() # todo: implement to collect blinds
#     261         self.deal()
# --> 262         self.do_betting_round()
#     263         self.expose_flop()
#     264         self.do_betting_round()
#
# ~/dev/cards/src/model/holdem_round.py in do_betting_round(self)
#     154             if not active_player.folded:
#     155                 print(f"The bet is {self.table.bet_amount} to {active_player.name}")
# --> 156                 action = active_player.play(self.table)
#     157                 print(f"Got action: {action}")
#     158                 self.handle_action(action, active_player)
#
# ~/dev/cards/src/players/callie_calls.py in play(self, table, is_called)
#       7             action = Action("CALL", table.bet_amount)
#       8         else:
# ----> 9             action = Action("CALL", self.bankroll + self.status.money_on_table, all_in=True)
#      10         print(f"Play - {self.name}: {action.action_type}")
#      11         return action
#
# ~/dev/cards/src/model/action.py in __init__(self, action_type, amount, all_in)
#      20         if not amount:
#      21             if action_type in [RAISE, CALL, MATCH]:
# ---> 22                 raise Exception(f"Invalid MATCH, RAISE or CALL amount (None)")
#      23         else:
#      24             if action_type in [CHECK, FOLD]:
#
# Exception: Invalid MATCH, RAISE or CALL amount (None)

# %%
players
# Out:
# [Player(Josh, 35),
#  Player(Madi, 378.0),
#  Player(Cody, 96),
#  Player(Michelle, 138.0),
#  Player(Sophia, 0),
#  Player(Beezie, 92)]

# %%
# Out:
# 35
