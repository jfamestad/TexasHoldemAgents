# %%
from model.table import Table

from model.holdem_round import HoldemRound
from players.floyd_folds import Floyd
from players.callie_calls import Callie
from players.robby_random import Robby
from players.ricky_raise import Ricky

# %%
players = [
    Ricky("Josh", 100),
    Robby("Cody", 100),
    Ricky("Beezie", 100),
    Callie("Madi", 100),
#     Floyd("Cody", 100),
    Robby("Michelle", 100),
    Callie("Sophia", 100),
#     Floyd("Beezie", 100)
]

# %%
players, table = HoldemRound(
    players=players,
    blind=1
).play()
# Out:
# Collecting blinds
# Sophia is placing big blind: 2
# Sophia placed big blind: 98 left in bankroll
# Michelle is placing small blind: 1
# Michelle placed small blind: 99 left in bankroll
# delt Josh to Card("7", "Spades")
# delt Cody to Card("10", "Hearts")
# delt Beezie to Card("9", "Spades")
# delt Madi to Card("10", "Diamonds")
# delt Michelle to Card("9", "Clubs")
# delt Sophia to Card("4", "Clubs")
# delt Josh to Card("6", "Hearts")
# delt Cody to Card("6", "Clubs")
# delt Beezie to Card("8", "Clubs")
# delt Madi to Card("10", "Spades")
# delt Michelle to Card("7", "Clubs")
# delt Sophia to Card("6", "Spades")
# Starting betting round
# The bet is 2 to Cody
# Cody wants to raise. Current Bet is 2, Cody has 100
# Play - Cody: RAISE
# Got action: Action(RAISE, 37)
# handling action: Action(RAISE, 37)
# Processing Action - Cody: RAISE
# Cody: 100
# Action amount: 37
# Money on table: 0
# Cash into the pot: 37
# Cash into pot: 37
# Cody calling, raising, or matching by 37
# Cody still has: 63 in their bankroll
# Cody raises
# The bet is 37 to Beezie
# Beezie has a max bet of 100
# Play - Beezie: RAISE
# Got action: Action(RAISE, 71)
# handling action: Action(RAISE, 71)
# Processing Action - Beezie: RAISE
# Beezie: 100
# Action amount: 71
# Money on table: 0
# Cash into the pot: 71
# Cash into pot: 71
# Beezie calling, raising, or matching by 71
# Beezie still has: 29 in their bankroll
# Beezie raises
# The bet is 71 to Madi
# Madi sees the bet is at: 71
# Madi has a max bet of 100
# Play - Madi: CALL
# Got action: Action(CALL, 71)
# handling action: Action(CALL, 71)
# Processing Action - Madi: CALL
# Madi: 100
# Action amount: 71
# Money on table: 0
# Cash into the pot: 71
# Cash into pot: 71
# Madi calling, raising, or matching by 71
# Madi still has: 29 in their bankroll
# The bet is 71 to Michelle
# Michelle wants to raise. Current Bet is 71, Michelle has 99
# Play - Michelle: RAISE
# Got action: Action(RAISE, 77)
# handling action: Action(RAISE, 77)
# Processing Action - Michelle: RAISE
# Michelle: 99
# Action amount: 77
# Money on table: 1
# Cash into the pot: 76
# Cash into pot: 76
# Michelle calling, raising, or matching by 77
# Michelle still has: 23 in their bankroll
# Michelle raises
# The bet is 77 to Sophia
# Sophia sees the bet is at: 77
# Sophia has a max bet of 100
# Play - Sophia: CALL
# Got action: Action(CALL, 77)
# handling action: Action(CALL, 77)
# Processing Action - Sophia: CALL
# Sophia: 98
# Action amount: 77
# Money on table: 2
# Cash into the pot: 75
# Cash into pot: 75
# Sophia calling, raising, or matching by 77
# Sophia still has: 23 in their bankroll
# The bet is 77 to Josh
# Josh has a max bet of 100
# Play - Josh: RAISE
# Got action: Action(RAISE, 83)
# handling action: Action(RAISE, 83)
# Processing Action - Josh: RAISE
# Josh: 100
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Josh calling, raising, or matching by 83
# Josh still has: 17 in their bankroll
# Josh raises
# The bet is 83 to Cody
# Play - Cody: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Cody: CALL
# Cody: 63
# Action amount: 83
# Money on table: 37
# Cash into the pot: 46
# Cash into pot: 46
# Cody calling, raising, or matching by 83
# Cody still has: 17 in their bankroll
# Cody calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Josh', 'Cody', 'Beezie', 'Madi', 'Michelle', 'Sophia']
# Round is called. Match or Fold to Beezie
# Called - Active Player: Beezie
# Beezie has a max bet of 100
# Play - Beezie: MATCH
# handling action: Action(MATCH, 83)
# Processing Action - Beezie: MATCH
# Beezie: 29
# Action amount: 83
# Money on table: 71
# Cash into the pot: 12
# Cash into pot: 12
# Beezie calling, raising, or matching by 83
# Beezie still has: 17 in their bankroll
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 100
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 29
# Action amount: 83
# Money on table: 71
# Cash into the pot: 12
# Cash into pot: 12
# Madi calling, raising, or matching by 83
# Madi still has: 17 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Michelle
# Called - Active Player: Michelle
# Michelle has a max bet of 100
# Play - Michelle: FOLD
# handling action: Action(FOLD, None)
# Processing Action - Michelle: FOLD
# Michelle: 23
# Michelle: FOLD
# Michelle is folding: 23
# Michelle folds
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 100
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 23
# Action amount: 83
# Money on table: 77
# Cash into the pot: 6
# Cash into pot: 6
# Sophia calling, raising, or matching by 83
# Sophia still has: 17 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Called - Active Player: Josh
# Josh has a max bet of 100
# Play - Josh: MATCH
# handling action: Action(MATCH, 83)
# Processing Action - Josh: MATCH
# Josh: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Josh calling, raising, or matching by 83
# Josh still has: 17 in their bankroll
# Betting round is complete
# Players still in: ['Josh', 'Cody', 'Beezie', 'Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Cody
# Play - Cody: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Cody: CALL
# Cody: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Cody calling, raising, or matching by 83
# Cody still has: 17 in their bankroll
# Cody calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Josh', 'Cody', 'Beezie', 'Madi', 'Sophia']
# Round is called. Match or Fold to Beezie
# Called - Active Player: Beezie
# Beezie has a max bet of 100
# Play - Beezie: MATCH
# handling action: Action(MATCH, 83)
# Processing Action - Beezie: MATCH
# Beezie: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Beezie calling, raising, or matching by 83
# Beezie still has: 17 in their bankroll
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 100
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 17 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 100
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 17 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Called - Active Player: Josh
# Josh has a max bet of 100
# Play - Josh: MATCH
# handling action: Action(MATCH, 83)
# Processing Action - Josh: MATCH
# Josh: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Josh calling, raising, or matching by 83
# Josh still has: 17 in their bankroll
# Betting round is complete
# Players still in: ['Josh', 'Cody', 'Beezie', 'Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Cody
# Play - Cody: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Cody: CALL
# Cody: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Cody calling, raising, or matching by 83
# Cody still has: 17 in their bankroll
# Cody calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Josh', 'Cody', 'Beezie', 'Madi', 'Sophia']
# Round is called. Match or Fold to Beezie
# Called - Active Player: Beezie
# Beezie has a max bet of 100
# Play - Beezie: MATCH
# handling action: Action(MATCH, 83)
# Processing Action - Beezie: MATCH
# Beezie: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Beezie calling, raising, or matching by 83
# Beezie still has: 17 in their bankroll
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 100
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 17 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 100
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 17 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Called - Active Player: Josh
# Josh has a max bet of 100
# Play - Josh: MATCH
# handling action: Action(MATCH, 83)
# Processing Action - Josh: MATCH
# Josh: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Josh calling, raising, or matching by 83
# Josh still has: 17 in their bankroll
# Betting round is complete
# Players still in: ['Josh', 'Cody', 'Beezie', 'Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Cody
# Play - Cody: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Cody: CALL
# Cody: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Cody calling, raising, or matching by 83
# Cody still has: 17 in their bankroll
# Cody calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Josh', 'Cody', 'Beezie', 'Madi', 'Sophia']
# Round is called. Match or Fold to Beezie
# Called - Active Player: Beezie
# Beezie has a max bet of 100
# Play - Beezie: MATCH
# handling action: Action(MATCH, 83)
# Processing Action - Beezie: MATCH
# Beezie: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Beezie calling, raising, or matching by 83
# Beezie still has: 17 in their bankroll
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 100
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 17 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 100
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 17 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Called - Active Player: Josh
# Josh has a max bet of 100
# Play - Josh: MATCH
# handling action: Action(MATCH, 83)
# Processing Action - Josh: MATCH
# Josh: 17
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Josh calling, raising, or matching by 83
# Josh still has: 17 in their bankroll
# Betting round is complete
# Players still in: ['Josh', 'Cody', 'Beezie', 'Madi', 'Sophia']
# Josh is holding [Card("7", "Spades"), Card("6", "Hearts")]
# Josh makes a hand from: [Card("7", "Spades"), Card("6", "Hearts"), Card("7", "Spades"), Card("6", "Hearts"), Card("6", "Diamonds"), Card("8", "Spades"), Card("9", "Diamonds"), Card("A", "Clubs"), Card("J", "Diamonds")]
# Josh presents hand: 7S, 6H, 7S, 6H, 6D
# Cody is holding [Card("10", "Hearts"), Card("6", "Clubs")]
# Cody makes a hand from: [Card("10", "Hearts"), Card("6", "Clubs"), Card("10", "Hearts"), Card("6", "Clubs"), Card("6", "Diamonds"), Card("8", "Spades"), Card("9", "Diamonds"), Card("A", "Clubs"), Card("J", "Diamonds")]
# Cody presents hand: 10H, 6C, 10H, 6C, 6D
# Beezie is holding [Card("9", "Spades"), Card("8", "Clubs")]
# Beezie makes a hand from: [Card("9", "Spades"), Card("8", "Clubs"), Card("9", "Spades"), Card("8", "Clubs"), Card("6", "Diamonds"), Card("8", "Spades"), Card("9", "Diamonds"), Card("A", "Clubs"), Card("J", "Diamonds")]
# Beezie presents hand: 8C, 9S, 8C, 8S, 9D
# Madi is holding [Card("10", "Diamonds"), Card("10", "Spades")]
# Madi makes a hand from: [Card("10", "Diamonds"), Card("10", "Spades"), Card("10", "Diamonds"), Card("10", "Spades"), Card("6", "Diamonds"), Card("8", "Spades"), Card("9", "Diamonds"), Card("A", "Clubs"), Card("J", "Diamonds")]
# Madi presents hand: 10D, 10S, 10D, 10S, AC
# Sophia is holding [Card("4", "Clubs"), Card("6", "Spades")]
# Sophia makes a hand from: [Card("4", "Clubs"), Card("6", "Spades"), Card("4", "Clubs"), Card("6", "Spades"), Card("6", "Diamonds"), Card("8", "Spades"), Card("9", "Diamonds"), Card("A", "Clubs"), Card("J", "Diamonds")]
# Sophia presents hand: 4C, 6S, 4C, 6S, 6D
# Josh is holding [Card("7", "Spades"), Card("6", "Hearts"), Card("7", "Spades"), Card("6", "Hearts"), Card("6", "Diamonds"), Card("8", "Spades"), Card("9", "Diamonds"), Card("A", "Clubs"), Card("J", "Diamonds")]
# Josh presents hand: 7S, 6H, 7S, 6H, 6D
# Cody is holding [Card("10", "Hearts"), Card("6", "Clubs"), Card("10", "Hearts"), Card("6", "Clubs"), Card("6", "Diamonds"), Card("8", "Spades"), Card("9", "Diamonds"), Card("A", "Clubs"), Card("J", "Diamonds")]
# Cody presents hand: 10H, 6C, 10H, 6C, 6D
# Beezie is holding [Card("9", "Spades"), Card("8", "Clubs"), Card("9", "Spades"), Card("8", "Clubs"), Card("6", "Diamonds"), Card("8", "Spades"), Card("9", "Diamonds"), Card("A", "Clubs"), Card("J", "Diamonds")]
# Beezie presents hand: 8C, 9S, 8C, 8S, 9D
# Madi is holding [Card("10", "Diamonds"), Card("10", "Spades"), Card("10", "Diamonds"), Card("10", "Spades"), Card("6", "Diamonds"), Card("8", "Spades"), Card("9", "Diamonds"), Card("A", "Clubs"), Card("J", "Diamonds")]
# Madi presents hand: 10D, 10S, 10D, 10S, AC
# Sophia is holding [Card("4", "Clubs"), Card("6", "Spades"), Card("4", "Clubs"), Card("6", "Spades"), Card("6", "Diamonds"), Card("8", "Spades"), Card("9", "Diamonds"), Card("A", "Clubs"), Card("J", "Diamonds")]
# Sophia presents hand: 4C, 6S, 4C, 6S, 6D
# Winning Hand: 10D, 10S, 10D, 10S, AC
# ('FOUR_OF_A_KIND', '10'): 10D, 10S, 10D, 10S, AC
# ['Madi']
# Flop: [Card("6", "Diamonds"), Card("8", "Spades"), Card("9", "Diamonds")]
# Turn: Card("A", "Clubs")
# River: Card("J", "Diamonds")
# Madi collects a $492.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 17)
# Player(Cody, 17)
# Player(Beezie, 17)
# Player(Madi, 509.0)
# Player(Michelle, 23)
# Player(Sophia, 17)

# %%
[player for player in players if player.bankroll > 0]
# Out:
# [Player(Josh, 17),
#  Player(Cody, 17),
#  Player(Beezie, 17),
#  Player(Madi, 509.0),
#  Player(Michelle, 23),
#  Player(Sophia, 17)]

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > 0],
    table=table
).play()
# Out:
# Collecting blinds
# Josh is placing big blind: 2
# Josh placed big blind: 15 left in bankroll
# Sophia is placing small blind: 1
# Sophia placed small blind: 16 left in bankroll
# delt Josh to Card("K", "Spades")
# delt Cody to Card("3", "Hearts")
# delt Beezie to Card("A", "Clubs")
# delt Madi to Card("4", "Diamonds")
# delt Michelle to Card("8", "Clubs")
# delt Sophia to Card("J", "Hearts")
# delt Josh to Card("4", "Hearts")
# delt Cody to Card("3", "Spades")
# delt Beezie to Card("A", "Hearts")
# delt Madi to Card("J", "Diamonds")
# delt Michelle to Card("9", "Spades")
# delt Sophia to Card("9", "Diamonds")
# Starting betting round
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 17
# Beezie: FOLD
# Beezie is folding: 17
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 509.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 509.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Madi calling, raising, or matching by 83
# Madi still has: 426.0 in their bankroll
# The bet is 83 to Michelle
# Play - Michelle: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Michelle: FOLD
# Michelle: 23
# Michelle: FOLD
# Michelle is folding: 23
# Michelle folds
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 17
# Sophia is all in
# Sophia has 16 in the bank and 1 on the table
# Sophia has a max bet of 17
# Play - Sophia: CALL
# Got action: Action(CALL, 17)
# handling action: Action(CALL, 17)
# Processing Action - Sophia: CALL
# Sophia: 16
# Action amount: 17
# Money on table: 1
# Cash into the pot: 16
# Cash into pot: 16
# Sophia calling, raising, or matching by 17
# Sophia still has: 0 in their bankroll
# Splitting pot - Sophia is all in
# Players: ['Josh', 'Cody', 'Madi', 'Sophia']
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 15
# Josh: FOLD
# Josh is folding: 15
# Josh folds
# The bet is 83 to Cody
# Cody wants to raise. Current Bet is 83, Cody has 17
# <> Cody is all in <>
# Play - Cody: CALL
# Got action: Action(CALL, 17)
# handling action: Action(CALL, 17)
# Processing Action - Cody: CALL
# Cody: 17
# Action amount: 17
# Money on table: 0
# Cash into the pot: 17
# Cash into pot: 17
# Cody calling, raising, or matching by 17
# Cody still has: 0 in their bankroll
# Cody calls, setting holdem_round.is_called = True
# Splitting pot - Cody is all in
# Players: ['Cody', 'Madi', 'Sophia']
# Betting is called...settling up with  remaining players
# Players still in: ['Cody', 'Madi', 'Sophia']
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 509.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 426.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 426.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 17
# Sophia is all in
# Sophia has 0 in the bank and 17 on the table
# Sophia has a max bet of 17
# Play - Sophia: CALL
# handling action: Action(CALL, 17)
# Processing Action - Sophia: CALL
# Sophia: 0
# Action amount: 17
# Money on table: 17
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 17
# Sophia still has: 0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Splitting pot - Sophia is all in
# Players: ['Cody', 'Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Betting round is complete
# Players still in: ['Cody', 'Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Cody
# Play - Cody: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Cody: FOLD
# Cody: 0
# Cody: FOLD
# Cody is folding: 0
# Cody folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 509.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 426.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 426.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 17
# Sophia is all in
# Sophia has 0 in the bank and 17 on the table
# Sophia has a max bet of 17
# Play - Sophia: CALL
# handling action: Action(CALL, 17)
# Processing Action - Sophia: CALL
# Sophia: 0
# Action amount: 17
# Money on table: 17
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 17
# Sophia still has: 0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Splitting pot - Sophia is all in
# Players: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 509.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 426.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 426.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 17
# Sophia is all in
# Sophia has 0 in the bank and 17 on the table
# Sophia has a max bet of 17
# Play - Sophia: CALL
# handling action: Action(CALL, 17)
# Processing Action - Sophia: CALL
# Sophia: 0
# Action amount: 17
# Money on table: 17
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 17
# Sophia still has: 0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Splitting pot - Sophia is all in
# Players: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 509.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 426.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 426.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 17
# Sophia is all in
# Sophia has 0 in the bank and 17 on the table
# Sophia has a max bet of 17
# Play - Sophia: CALL
# handling action: Action(CALL, 17)
# Processing Action - Sophia: CALL
# Sophia: 0
# Action amount: 17
# Money on table: 17
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 17
# Sophia still has: 0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Splitting pot - Sophia is all in
# Players: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Cody
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("4", "Diamonds"), Card("J", "Diamonds")]
# Madi makes a hand from: [Card("4", "Diamonds"), Card("J", "Diamonds"), Card("4", "Diamonds"), Card("J", "Diamonds"), Card("6", "Spades"), Card("9", "Hearts"), Card("9", "Clubs"), Card("J", "Spades"), Card("5", "Hearts")]
# Madi presents hand: JD, JD, 9H, 9C, JS
# Sophia is holding [Card("J", "Hearts"), Card("9", "Diamonds")]
# Sophia makes a hand from: [Card("J", "Hearts"), Card("9", "Diamonds"), Card("J", "Hearts"), Card("9", "Diamonds"), Card("6", "Spades"), Card("9", "Hearts"), Card("9", "Clubs"), Card("J", "Spades"), Card("5", "Hearts")]
# Sophia presents hand: JH, 9D, 9D, 9H, 9C
# Madi is holding [Card("4", "Diamonds"), Card("J", "Diamonds"), Card("4", "Diamonds"), Card("J", "Diamonds"), Card("6", "Spades"), Card("9", "Hearts"), Card("9", "Clubs"), Card("J", "Spades"), Card("5", "Hearts")]
# Madi presents hand: JD, JD, 9H, 9C, JS
# Sophia is holding [Card("J", "Hearts"), Card("9", "Diamonds"), Card("J", "Hearts"), Card("9", "Diamonds"), Card("6", "Spades"), Card("9", "Hearts"), Card("9", "Clubs"), Card("J", "Spades"), Card("5", "Hearts")]
# Sophia presents hand: JH, 9D, 9D, 9H, 9C
# Winning Hand: JH, 9D, 9D, 9H, 9C
# ('FOUR_OF_A_KIND', '9'): JH, 9D, 9D, 9H, 9C
# ['Sophia']
# Flop: [Card("6", "Spades"), Card("9", "Hearts"), Card("9", "Clubs")]
# Turn: Card("J", "Spades")
# River: Card("5", "Hearts")
# Sophia collects a $119.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 15)
# Player(Cody, 0)
# Player(Beezie, 17)
# Player(Madi, 426.0)
# Player(Michelle, 23)
# Player(Sophia, 119.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > 0],
    table=table
).play()
# Out:
# Collecting blinds
# Beezie is placing big blind: 2
# Beezie placed big blind: 15 left in bankroll
# Josh is placing small blind: 1
# Josh placed small blind: 14 left in bankroll
# delt Josh to Card("5", "Hearts")
# delt Beezie to Card("8", "Clubs")
# delt Madi to Card("10", "Hearts")
# delt Michelle to Card("3", "Clubs")
# delt Sophia to Card("A", "Diamonds")
# delt Josh to Card("8", "Spades")
# delt Beezie to Card("2", "Hearts")
# delt Madi to Card("J", "Hearts")
# delt Michelle to Card("6", "Spades")
# delt Sophia to Card("7", "Hearts")
# Starting betting round
# The bet is 83 to Michelle
# Michelle wants to raise. Current Bet is 83, Michelle has 23
# <> Michelle is all in <>
# Play - Michelle: CALL
# Got action: Action(CALL, 23)
# handling action: Action(CALL, 23)
# Processing Action - Michelle: CALL
# Michelle: 23
# Action amount: 23
# Money on table: 0
# Cash into the pot: 23
# Cash into pot: 23
# Michelle calling, raising, or matching by 23
# Michelle still has: 0 in their bankroll
# Splitting pot - Michelle is all in
# Players: ['Josh', 'Beezie', 'Madi', 'Michelle', 'Sophia']
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 119.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 119.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Sophia calling, raising, or matching by 83
# Sophia still has: 36.0 in their bankroll
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 14
# Josh: FOLD
# Josh is folding: 14
# Josh folds
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 15
# Beezie: FOLD
# Beezie is folding: 15
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 426.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 426.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Madi calling, raising, or matching by 83
# Madi still has: 343.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Michelle', 'Sophia']
# Round is called. Match or Fold to Michelle
# Called - Active Player: Michelle
# Michelle has a max bet of 23
# Play - Michelle: MATCH
# handling action: Action(MATCH, 23)
# Processing Action - Michelle: MATCH
# Michelle: 0
# Action amount: 23
# Money on table: 23
# Cash into the pot: 0
# Cash into pot: 0
# Michelle calling, raising, or matching by 23
# Michelle still has: 0 in their bankroll
# Splitting pot - Michelle is all in
# Players: ['Madi', 'Michelle', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 119.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 36.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 36.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Michelle', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 426.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 343.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 343.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Michelle', 'Sophia']
# Round is called. Match or Fold to Michelle
# Called - Active Player: Michelle
# Michelle has a max bet of 23
# Play - Michelle: MATCH
# handling action: Action(MATCH, 23)
# Processing Action - Michelle: MATCH
# Michelle: 0
# Action amount: 23
# Money on table: 23
# Cash into the pot: 0
# Cash into pot: 0
# Michelle calling, raising, or matching by 23
# Michelle still has: 0 in their bankroll
# Splitting pot - Michelle is all in
# Players: ['Madi', 'Michelle', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 119.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 36.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 36.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Michelle', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 426.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 343.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 343.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Michelle', 'Sophia']
# Round is called. Match or Fold to Michelle
# Called - Active Player: Michelle
# Michelle has a max bet of 23
# Play - Michelle: FOLD
# handling action: Action(FOLD, None)
# Processing Action - Michelle: FOLD
# Michelle: 0
# Michelle: FOLD
# Michelle is folding: 0
# Michelle folds
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 119.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 36.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 36.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 426.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 343.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 343.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Michelle
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 119.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 36.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 36.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("10", "Hearts"), Card("J", "Hearts")]
# Madi makes a hand from: [Card("10", "Hearts"), Card("J", "Hearts"), Card("10", "Hearts"), Card("J", "Hearts"), Card("9", "Clubs"), Card("A", "Clubs"), Card("5", "Spades"), Card("7", "Spades"), Card("6", "Hearts")]
# Madi presents hand: 10H, JH, 10H, JH, 6H
# Sophia is holding [Card("A", "Diamonds"), Card("7", "Hearts")]
# Sophia makes a hand from: [Card("A", "Diamonds"), Card("7", "Hearts"), Card("A", "Diamonds"), Card("7", "Hearts"), Card("9", "Clubs"), Card("A", "Clubs"), Card("5", "Spades"), Card("7", "Spades"), Card("6", "Hearts")]
# Sophia presents hand: 7H, AD, 7H, AC, 7S
# Madi is holding [Card("10", "Hearts"), Card("J", "Hearts"), Card("10", "Hearts"), Card("J", "Hearts"), Card("9", "Clubs"), Card("A", "Clubs"), Card("5", "Spades"), Card("7", "Spades"), Card("6", "Hearts")]
# Madi presents hand: 10H, JH, 10H, JH, 6H
# Sophia is holding [Card("A", "Diamonds"), Card("7", "Hearts"), Card("A", "Diamonds"), Card("7", "Hearts"), Card("9", "Clubs"), Card("A", "Clubs"), Card("5", "Spades"), Card("7", "Spades"), Card("6", "Hearts")]
# Sophia presents hand: 7H, AD, 7H, AC, 7S
# Winning Hand: 7H, AD, 7H, AC, 7S
# ('FULL_HOUSE', '7', 'A'): 7H, AD, 7H, AC, 7S
# ['Sophia']
# Flop: [Card("9", "Clubs"), Card("A", "Clubs"), Card("5", "Spades")]
# Turn: Card("7", "Spades")
# River: Card("6", "Hearts")
# Sophia collects a $192.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 14)
# Player(Beezie, 15)
# Player(Madi, 343.0)
# Player(Michelle, 0)
# Player(Sophia, 228.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > 0],
    table=table
).play()
# Out:
# Collecting blinds
# Madi is placing big blind: 2
# Madi placed big blind: 341.0 left in bankroll
# Beezie is placing small blind: 1
# Beezie placed small blind: 14 left in bankroll
# delt Josh to Card("A", "Diamonds")
# delt Beezie to Card("7", "Diamonds")
# delt Madi to Card("J", "Clubs")
# delt Sophia to Card("7", "Spades")
# delt Josh to Card("6", "Clubs")
# delt Beezie to Card("8", "Diamonds")
# delt Madi to Card("10", "Diamonds")
# delt Sophia to Card("2", "Spades")
# Starting betting round
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 14
# Josh: FOLD
# Josh is folding: 14
# Josh folds
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 14
# Beezie: FOLD
# Beezie is folding: 14
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 343.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 341.0
# Action amount: 83
# Money on table: 2
# Cash into the pot: 81
# Cash into pot: 81
# Madi calling, raising, or matching by 83
# Madi still has: 260.0 in their bankroll
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 228.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 228.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Sophia calling, raising, or matching by 83
# Sophia still has: 145.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 343.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 260.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 260.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 228.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 145.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 145.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 343.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 260.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 260.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 228.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 145.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 145.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 343.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 260.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 260.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 228.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 145.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 145.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 343.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 260.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 260.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("J", "Clubs"), Card("10", "Diamonds")]
# Madi makes a hand from: [Card("J", "Clubs"), Card("10", "Diamonds"), Card("J", "Clubs"), Card("10", "Diamonds"), Card("3", "Spades"), Card("Q", "Clubs"), Card("2", "Diamonds"), Card("4", "Hearts"), Card("Q", "Spades")]
# Madi presents hand: JC, 10D, JC, QC, QS
# Sophia is holding [Card("7", "Spades"), Card("2", "Spades")]
# Sophia makes a hand from: [Card("7", "Spades"), Card("2", "Spades"), Card("7", "Spades"), Card("2", "Spades"), Card("3", "Spades"), Card("Q", "Clubs"), Card("2", "Diamonds"), Card("4", "Hearts"), Card("Q", "Spades")]
# Sophia presents hand: 2S, 2S, QC, 2D, QS
# Madi is holding [Card("J", "Clubs"), Card("10", "Diamonds"), Card("J", "Clubs"), Card("10", "Diamonds"), Card("3", "Spades"), Card("Q", "Clubs"), Card("2", "Diamonds"), Card("4", "Hearts"), Card("Q", "Spades")]
# Madi presents hand: JC, 10D, JC, QC, QS
# Sophia is holding [Card("7", "Spades"), Card("2", "Spades"), Card("7", "Spades"), Card("2", "Spades"), Card("3", "Spades"), Card("Q", "Clubs"), Card("2", "Diamonds"), Card("4", "Hearts"), Card("Q", "Spades")]
# Sophia presents hand: 2S, 2S, QC, 2D, QS
# Winning Hand: 2S, 2S, QC, 2D, QS
# ('FULL_HOUSE', '2', 'Q'): 2S, 2S, QC, 2D, QS
# ['Sophia']
# Flop: [Card("3", "Spades"), Card("Q", "Clubs"), Card("2", "Diamonds")]
# Turn: Card("4", "Hearts")
# River: Card("Q", "Spades")
# Sophia collects a $167.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 14)
# Player(Beezie, 14)
# Player(Madi, 260.0)
# Player(Sophia, 312.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > 0],
    table=table
).play()
# Out:
# Collecting blinds
# Sophia is placing big blind: 2
# Sophia placed big blind: 310.0 left in bankroll
# Madi is placing small blind: 1
# Madi placed small blind: 259.0 left in bankroll
# delt Josh to Card("9", "Diamonds")
# delt Beezie to Card("8", "Diamonds")
# delt Madi to Card("K", "Clubs")
# delt Sophia to Card("J", "Diamonds")
# delt Josh to Card("3", "Clubs")
# delt Beezie to Card("9", "Hearts")
# delt Madi to Card("10", "Diamonds")
# delt Sophia to Card("A", "Diamonds")
# Starting betting round
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 14
# Beezie: FOLD
# Beezie is folding: 14
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 260.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 259.0
# Action amount: 83
# Money on table: 1
# Cash into the pot: 82
# Cash into pot: 82
# Madi calling, raising, or matching by 83
# Madi still has: 177.0 in their bankroll
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 312.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 310.0
# Action amount: 83
# Money on table: 2
# Cash into the pot: 81
# Cash into pot: 81
# Sophia calling, raising, or matching by 83
# Sophia still has: 229.0 in their bankroll
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 14
# Josh: FOLD
# Josh is folding: 14
# Josh folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 260.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 177.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 177.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 312.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 229.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 229.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 260.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 177.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 177.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 312.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 229.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 229.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 260.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 177.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 177.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 312.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 229.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 229.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 260.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 177.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 177.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 312.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 229.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 229.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("K", "Clubs"), Card("10", "Diamonds")]
# Madi makes a hand from: [Card("K", "Clubs"), Card("10", "Diamonds"), Card("K", "Clubs"), Card("10", "Diamonds"), Card("5", "Clubs"), Card("4", "Hearts"), Card("Q", "Diamonds"), Card("8", "Spades"), Card("8", "Clubs")]
# Madi presents hand: KC, KC, QD, 8S, 8C
# Sophia is holding [Card("J", "Diamonds"), Card("A", "Diamonds")]
# Sophia makes a hand from: [Card("J", "Diamonds"), Card("A", "Diamonds"), Card("J", "Diamonds"), Card("A", "Diamonds"), Card("5", "Clubs"), Card("4", "Hearts"), Card("Q", "Diamonds"), Card("8", "Spades"), Card("8", "Clubs")]
# Sophia presents hand: JD, AD, JD, AD, QD
# Madi is holding [Card("K", "Clubs"), Card("10", "Diamonds"), Card("K", "Clubs"), Card("10", "Diamonds"), Card("5", "Clubs"), Card("4", "Hearts"), Card("Q", "Diamonds"), Card("8", "Spades"), Card("8", "Clubs")]
# Madi presents hand: KC, KC, QD, 8S, 8C
# Sophia is holding [Card("J", "Diamonds"), Card("A", "Diamonds"), Card("J", "Diamonds"), Card("A", "Diamonds"), Card("5", "Clubs"), Card("4", "Hearts"), Card("Q", "Diamonds"), Card("8", "Spades"), Card("8", "Clubs")]
# Sophia presents hand: JD, AD, JD, AD, QD
# Winning Hand: JD, AD, JD, AD, QD
# ('FLUSH', Card("A", "Diamonds")): JD, AD, JD, AD, QD
# ['Sophia']
# Flop: [Card("5", "Clubs"), Card("4", "Hearts"), Card("Q", "Diamonds")]
# Turn: Card("8", "Spades")
# River: Card("8", "Clubs")
# Sophia collects a $166.0 pot

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > table.big_blind],
    table=table
).play()
# Out:
# Collecting blinds
# Josh is placing big blind: 2
# Josh placed big blind: 12 left in bankroll
# Sophia is placing small blind: 1
# Sophia placed small blind: 394.0 left in bankroll
# delt Josh to Card("6", "Hearts")
# delt Beezie to Card("3", "Clubs")
# delt Madi to Card("J", "Clubs")
# delt Sophia to Card("7", "Spades")
# delt Josh to Card("Q", "Diamonds")
# delt Beezie to Card("7", "Hearts")
# delt Madi to Card("5", "Hearts")
# delt Sophia to Card("K", "Spades")
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 177.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 177.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Madi calling, raising, or matching by 83
# Madi still has: 94.0 in their bankroll
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 395.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 394.0
# Action amount: 83
# Money on table: 1
# Cash into the pot: 82
# Cash into pot: 82
# Sophia calling, raising, or matching by 83
# Sophia still has: 312.0 in their bankroll
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 12
# Josh: FOLD
# Josh is folding: 12
# Josh folds
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 14
# Beezie: FOLD
# Beezie is folding: 14
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 177.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 94.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 94.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 395.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 312.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 312.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 177.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 94.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 94.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 395.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 312.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 312.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 177.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 94.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 94.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 395.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 312.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 312.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 177.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 94.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 94.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 395.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 312.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 312.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("J", "Clubs"), Card("5", "Hearts")]
# Madi makes a hand from: [Card("J", "Clubs"), Card("5", "Hearts"), Card("J", "Clubs"), Card("5", "Hearts"), Card("2", "Clubs"), Card("5", "Clubs"), Card("8", "Spades"), Card("8", "Clubs"), Card("10", "Hearts")]
# Madi presents hand: JC, 5H, JC, 5H, 5C
# Sophia is holding [Card("7", "Spades"), Card("K", "Spades")]
# Sophia makes a hand from: [Card("7", "Spades"), Card("K", "Spades"), Card("7", "Spades"), Card("K", "Spades"), Card("2", "Clubs"), Card("5", "Clubs"), Card("8", "Spades"), Card("8", "Clubs"), Card("10", "Hearts")]
# Sophia presents hand: 7S, KS, 7S, KS, 8S
# Madi is holding [Card("J", "Clubs"), Card("5", "Hearts"), Card("J", "Clubs"), Card("5", "Hearts"), Card("2", "Clubs"), Card("5", "Clubs"), Card("8", "Spades"), Card("8", "Clubs"), Card("10", "Hearts")]
# Madi presents hand: JC, 5H, JC, 5H, 5C
# Sophia is holding [Card("7", "Spades"), Card("K", "Spades"), Card("7", "Spades"), Card("K", "Spades"), Card("2", "Clubs"), Card("5", "Clubs"), Card("8", "Spades"), Card("8", "Clubs"), Card("10", "Hearts")]
# Sophia presents hand: 7S, KS, 7S, KS, 8S
# Winning Hand: JC, 5H, JC, 5H, 5C
# ('FULL_HOUSE', '5', 'J'): JC, 5H, JC, 5H, 5C
# ['Madi']
# Flop: [Card("2", "Clubs"), Card("5", "Clubs"), Card("8", "Spades")]
# Turn: Card("8", "Clubs")
# River: Card("10", "Hearts")
# Madi collects a $168.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 12)
# Player(Beezie, 14)
# Player(Madi, 262.0)
# Player(Sophia, 312.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > table.big_blind],
    table=table
).play()
# Out:
# Collecting blinds
# Beezie is placing big blind: 2
# Beezie placed big blind: 12 left in bankroll
# Josh is placing small blind: 1
# Josh placed small blind: 11 left in bankroll
# delt Josh to Card("J", "Clubs")
# delt Beezie to Card("A", "Diamonds")
# delt Madi to Card("K", "Hearts")
# delt Sophia to Card("10", "Clubs")
# delt Josh to Card("4", "Diamonds")
# delt Beezie to Card("8", "Hearts")
# delt Madi to Card("5", "Diamonds")
# delt Sophia to Card("6", "Spades")
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 312.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 312.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Sophia calling, raising, or matching by 83
# Sophia still has: 229.0 in their bankroll
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 11
# Josh: FOLD
# Josh is folding: 11
# Josh folds
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 12
# Beezie: FOLD
# Beezie is folding: 12
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 262.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 262.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Madi calling, raising, or matching by 83
# Madi still has: 179.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 312.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 229.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 229.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 262.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 179.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 179.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 312.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 229.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 229.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 262.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 179.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 179.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 312.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 229.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 229.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 262.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 179.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 179.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 312.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 229.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 229.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("K", "Hearts"), Card("5", "Diamonds")]
# Madi makes a hand from: [Card("K", "Hearts"), Card("5", "Diamonds"), Card("K", "Hearts"), Card("5", "Diamonds"), Card("J", "Diamonds"), Card("4", "Hearts"), Card("7", "Clubs"), Card("A", "Hearts"), Card("2", "Hearts")]
# Madi presents hand: KH, KH, 4H, AH, 2H
# Sophia is holding [Card("10", "Clubs"), Card("6", "Spades")]
# Sophia makes a hand from: [Card("10", "Clubs"), Card("6", "Spades"), Card("10", "Clubs"), Card("6", "Spades"), Card("J", "Diamonds"), Card("4", "Hearts"), Card("7", "Clubs"), Card("A", "Hearts"), Card("2", "Hearts")]
# Sophia presents hand: 10C, 6S, 10C, 6S, AH
# Madi is holding [Card("K", "Hearts"), Card("5", "Diamonds"), Card("K", "Hearts"), Card("5", "Diamonds"), Card("J", "Diamonds"), Card("4", "Hearts"), Card("7", "Clubs"), Card("A", "Hearts"), Card("2", "Hearts")]
# Madi presents hand: KH, KH, 4H, AH, 2H
# Sophia is holding [Card("10", "Clubs"), Card("6", "Spades"), Card("10", "Clubs"), Card("6", "Spades"), Card("J", "Diamonds"), Card("4", "Hearts"), Card("7", "Clubs"), Card("A", "Hearts"), Card("2", "Hearts")]
# Sophia presents hand: 10C, 6S, 10C, 6S, AH
# Winning Hand: KH, KH, 4H, AH, 2H
# ('FLUSH', Card("K", "Hearts")): KH, KH, 4H, AH, 2H
# ['Madi']
# Flop: [Card("J", "Diamonds"), Card("4", "Hearts"), Card("7", "Clubs")]
# Turn: Card("A", "Hearts")
# River: Card("2", "Hearts")
# Madi collects a $169.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 11)
# Player(Beezie, 12)
# Player(Madi, 348.0)
# Player(Sophia, 229.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > table.big_blind],
    table=table
).play()
# Out:
# Collecting blinds
# Madi is placing big blind: 2
# Madi placed big blind: 346.0 left in bankroll
# Beezie is placing small blind: 1
# Beezie placed small blind: 11 left in bankroll
# delt Josh to Card("10", "Diamonds")
# delt Beezie to Card("Q", "Spades")
# delt Madi to Card("9", "Spades")
# delt Sophia to Card("J", "Diamonds")
# delt Josh to Card("7", "Spades")
# delt Beezie to Card("9", "Diamonds")
# delt Madi to Card("J", "Clubs")
# delt Sophia to Card("8", "Spades")
# Starting betting round
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 11
# Josh: FOLD
# Josh is folding: 11
# Josh folds
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 11
# Beezie: FOLD
# Beezie is folding: 11
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 348.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 346.0
# Action amount: 83
# Money on table: 2
# Cash into the pot: 81
# Cash into pot: 81
# Madi calling, raising, or matching by 83
# Madi still has: 265.0 in their bankroll
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 229.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 229.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Sophia calling, raising, or matching by 83
# Sophia still has: 146.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 348.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 265.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 265.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 229.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 146.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 146.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 348.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 265.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 265.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 229.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 146.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 146.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 348.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 265.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 265.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 229.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 146.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 146.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 348.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 265.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 265.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("9", "Spades"), Card("J", "Clubs")]
# Madi makes a hand from: [Card("9", "Spades"), Card("J", "Clubs"), Card("9", "Spades"), Card("J", "Clubs"), Card("6", "Spades"), Card("K", "Hearts"), Card("Q", "Diamonds"), Card("2", "Spades"), Card("7", "Diamonds")]
# Madi presents hand: 9S, JC, 9S, JC, KH
# Sophia is holding [Card("J", "Diamonds"), Card("8", "Spades")]
# Sophia makes a hand from: [Card("J", "Diamonds"), Card("8", "Spades"), Card("J", "Diamonds"), Card("8", "Spades"), Card("6", "Spades"), Card("K", "Hearts"), Card("Q", "Diamonds"), Card("2", "Spades"), Card("7", "Diamonds")]
# Sophia presents hand: JD, 8S, JD, 8S, KH
# Madi is holding [Card("9", "Spades"), Card("J", "Clubs"), Card("9", "Spades"), Card("J", "Clubs"), Card("6", "Spades"), Card("K", "Hearts"), Card("Q", "Diamonds"), Card("2", "Spades"), Card("7", "Diamonds")]
# Madi presents hand: 9S, JC, 9S, JC, KH
# Sophia is holding [Card("J", "Diamonds"), Card("8", "Spades"), Card("J", "Diamonds"), Card("8", "Spades"), Card("6", "Spades"), Card("K", "Hearts"), Card("Q", "Diamonds"), Card("2", "Spades"), Card("7", "Diamonds")]
# Sophia presents hand: JD, 8S, JD, 8S, KH
# Winning Hand: 9S, JC, 9S, JC, KH
# ('TWO_PAIR', ['9', 'J']): 9S, JC, 9S, JC, KH
# ['Madi']
# Flop: [Card("6", "Spades"), Card("K", "Hearts"), Card("Q", "Diamonds")]
# Turn: Card("2", "Spades")
# River: Card("7", "Diamonds")
# Madi collects a $167.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 11)
# Player(Beezie, 11)
# Player(Madi, 432.0)
# Player(Sophia, 146.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > table.big_blind],
    table=table
).play()
# Out:
# Collecting blinds
# Sophia is placing big blind: 2
# Sophia placed big blind: 144.0 left in bankroll
# Madi is placing small blind: 1
# Madi placed small blind: 431.0 left in bankroll
# delt Josh to Card("3", "Diamonds")
# delt Beezie to Card("8", "Hearts")
# delt Madi to Card("A", "Diamonds")
# delt Sophia to Card("Q", "Spades")
# delt Josh to Card("10", "Clubs")
# delt Beezie to Card("2", "Spades")
# delt Madi to Card("6", "Clubs")
# delt Sophia to Card("Q", "Clubs")
# Starting betting round
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 11
# Beezie: FOLD
# Beezie is folding: 11
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 432.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 431.0
# Action amount: 83
# Money on table: 1
# Cash into the pot: 82
# Cash into pot: 82
# Madi calling, raising, or matching by 83
# Madi still has: 349.0 in their bankroll
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 146.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 144.0
# Action amount: 83
# Money on table: 2
# Cash into the pot: 81
# Cash into pot: 81
# Sophia calling, raising, or matching by 83
# Sophia still has: 63.0 in their bankroll
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 11
# Josh: FOLD
# Josh is folding: 11
# Josh folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 432.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 349.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 349.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 146.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 63.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 63.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 432.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 349.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 349.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 146.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 63.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 63.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 432.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 349.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 349.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 146.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 63.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 63.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 432.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 349.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 349.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 146.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 63.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 63.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("A", "Diamonds"), Card("6", "Clubs")]
# Madi makes a hand from: [Card("A", "Diamonds"), Card("6", "Clubs"), Card("A", "Diamonds"), Card("6", "Clubs"), Card("6", "Hearts"), Card("9", "Spades"), Card("J", "Hearts"), Card("5", "Hearts"), Card("5", "Diamonds")]
# Madi presents hand: AD, 6C, AD, 6C, 6H
# Sophia is holding [Card("Q", "Spades"), Card("Q", "Clubs")]
# Sophia makes a hand from: [Card("Q", "Spades"), Card("Q", "Clubs"), Card("Q", "Spades"), Card("Q", "Clubs"), Card("6", "Hearts"), Card("9", "Spades"), Card("J", "Hearts"), Card("5", "Hearts"), Card("5", "Diamonds")]
# Sophia presents hand: QS, QC, QS, QC, JH
# Madi is holding [Card("A", "Diamonds"), Card("6", "Clubs"), Card("A", "Diamonds"), Card("6", "Clubs"), Card("6", "Hearts"), Card("9", "Spades"), Card("J", "Hearts"), Card("5", "Hearts"), Card("5", "Diamonds")]
# Madi presents hand: AD, 6C, AD, 6C, 6H
# Sophia is holding [Card("Q", "Spades"), Card("Q", "Clubs"), Card("Q", "Spades"), Card("Q", "Clubs"), Card("6", "Hearts"), Card("9", "Spades"), Card("J", "Hearts"), Card("5", "Hearts"), Card("5", "Diamonds")]
# Sophia presents hand: QS, QC, QS, QC, JH
# Winning Hand: QS, QC, QS, QC, JH
# ('FOUR_OF_A_KIND', 'Q'): QS, QC, QS, QC, JH
# ['Sophia']
# Flop: [Card("6", "Hearts"), Card("9", "Spades"), Card("J", "Hearts")]
# Turn: Card("5", "Hearts")
# River: Card("5", "Diamonds")
# Sophia collects a $166.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 11)
# Player(Beezie, 11)
# Player(Madi, 349.0)
# Player(Sophia, 229.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > table.big_blind],
    table=table
).play()
# Out:
# Collecting blinds
# Josh is placing big blind: 2
# Josh placed big blind: 9 left in bankroll
# Sophia is placing small blind: 1
# Sophia placed small blind: 228.0 left in bankroll
# delt Josh to Card("10", "Spades")
# delt Beezie to Card("K", "Spades")
# delt Madi to Card("6", "Spades")
# delt Sophia to Card("6", "Clubs")
# delt Josh to Card("Q", "Hearts")
# delt Beezie to Card("Q", "Spades")
# delt Madi to Card("8", "Diamonds")
# delt Sophia to Card("A", "Hearts")
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 349.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 349.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Madi calling, raising, or matching by 83
# Madi still has: 266.0 in their bankroll
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 229.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 228.0
# Action amount: 83
# Money on table: 1
# Cash into the pot: 82
# Cash into pot: 82
# Sophia calling, raising, or matching by 83
# Sophia still has: 146.0 in their bankroll
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 9
# Josh: FOLD
# Josh is folding: 9
# Josh folds
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 11
# Beezie: FOLD
# Beezie is folding: 11
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 349.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 266.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 266.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 229.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 146.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 146.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 349.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 266.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 266.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 229.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 146.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 146.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 349.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 266.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 266.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 229.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 146.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 146.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 349.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 266.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 266.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 229.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 146.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 146.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("6", "Spades"), Card("8", "Diamonds")]
# Madi makes a hand from: [Card("6", "Spades"), Card("8", "Diamonds"), Card("6", "Spades"), Card("8", "Diamonds"), Card("9", "Clubs"), Card("A", "Spades"), Card("8", "Clubs"), Card("7", "Hearts"), Card("10", "Clubs")]
# Madi presents hand: 6S, 8D, 6S, 8D, 8C
# Sophia is holding [Card("6", "Clubs"), Card("A", "Hearts")]
# Sophia makes a hand from: [Card("6", "Clubs"), Card("A", "Hearts"), Card("6", "Clubs"), Card("A", "Hearts"), Card("9", "Clubs"), Card("A", "Spades"), Card("8", "Clubs"), Card("7", "Hearts"), Card("10", "Clubs")]
# Sophia presents hand: 6C, AH, 6C, AH, AS
# Madi is holding [Card("6", "Spades"), Card("8", "Diamonds"), Card("6", "Spades"), Card("8", "Diamonds"), Card("9", "Clubs"), Card("A", "Spades"), Card("8", "Clubs"), Card("7", "Hearts"), Card("10", "Clubs")]
# Madi presents hand: 6S, 8D, 6S, 8D, 8C
# Sophia is holding [Card("6", "Clubs"), Card("A", "Hearts"), Card("6", "Clubs"), Card("A", "Hearts"), Card("9", "Clubs"), Card("A", "Spades"), Card("8", "Clubs"), Card("7", "Hearts"), Card("10", "Clubs")]
# Sophia presents hand: 6C, AH, 6C, AH, AS
# Winning Hand: 6C, AH, 6C, AH, AS
# ('FULL_HOUSE', 'A', '6'): 6C, AH, 6C, AH, AS
# ['Sophia']
# Flop: [Card("9", "Clubs"), Card("A", "Spades"), Card("8", "Clubs")]
# Turn: Card("7", "Hearts")
# River: Card("10", "Clubs")
# Sophia collects a $168.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 9)
# Player(Beezie, 11)
# Player(Madi, 266.0)
# Player(Sophia, 314.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > table.big_blind],
    table=table
).play()
# Out:
# Collecting blinds
# Beezie is placing big blind: 2
# Beezie placed big blind: 9 left in bankroll
# Josh is placing small blind: 1
# Josh placed small blind: 8 left in bankroll
# delt Josh to Card("4", "Clubs")
# delt Beezie to Card("J", "Spades")
# delt Madi to Card("K", "Clubs")
# delt Sophia to Card("10", "Spades")
# delt Josh to Card("10", "Hearts")
# delt Beezie to Card("3", "Spades")
# delt Madi to Card("7", "Hearts")
# delt Sophia to Card("5", "Hearts")
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 314.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 314.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Sophia calling, raising, or matching by 83
# Sophia still has: 231.0 in their bankroll
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 8
# Josh: FOLD
# Josh is folding: 8
# Josh folds
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 9
# Beezie: FOLD
# Beezie is folding: 9
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 266.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 266.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Madi calling, raising, or matching by 83
# Madi still has: 183.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 314.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 231.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 231.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 266.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 183.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 183.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 314.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 231.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 231.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 266.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 183.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 183.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 314.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 231.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 231.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 266.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 183.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 183.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 314.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 231.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 231.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("K", "Clubs"), Card("7", "Hearts")]
# Madi makes a hand from: [Card("K", "Clubs"), Card("7", "Hearts"), Card("K", "Clubs"), Card("7", "Hearts"), Card("8", "Clubs"), Card("5", "Clubs"), Card("6", "Hearts"), Card("6", "Diamonds"), Card("5", "Diamonds")]
# Madi presents hand: KC, 7H, 8C, 5C, 6H
# Sophia is holding [Card("10", "Spades"), Card("5", "Hearts")]
# Sophia makes a hand from: [Card("10", "Spades"), Card("5", "Hearts"), Card("10", "Spades"), Card("5", "Hearts"), Card("8", "Clubs"), Card("5", "Clubs"), Card("6", "Hearts"), Card("6", "Diamonds"), Card("5", "Diamonds")]
# Sophia presents hand: 10S, 5H, 5H, 5C, 5D
# Madi is holding [Card("K", "Clubs"), Card("7", "Hearts"), Card("K", "Clubs"), Card("7", "Hearts"), Card("8", "Clubs"), Card("5", "Clubs"), Card("6", "Hearts"), Card("6", "Diamonds"), Card("5", "Diamonds")]
# Madi presents hand: KC, 7H, 8C, 5C, 6H
# Sophia is holding [Card("10", "Spades"), Card("5", "Hearts"), Card("10", "Spades"), Card("5", "Hearts"), Card("8", "Clubs"), Card("5", "Clubs"), Card("6", "Hearts"), Card("6", "Diamonds"), Card("5", "Diamonds")]
# Sophia presents hand: 10S, 5H, 5H, 5C, 5D
# Winning Hand: 10S, 5H, 5H, 5C, 5D
# ('FOUR_OF_A_KIND', '5'): 10S, 5H, 5H, 5C, 5D
# ['Sophia']
# Flop: [Card("8", "Clubs"), Card("5", "Clubs"), Card("6", "Hearts")]
# Turn: Card("6", "Diamonds")
# River: Card("5", "Diamonds")
# Sophia collects a $169.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 8)
# Player(Beezie, 9)
# Player(Madi, 183.0)
# Player(Sophia, 400.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > table.big_blind],
    table=table
).play()
# Out:
# Collecting blinds
# Madi is placing big blind: 2
# Madi placed big blind: 181.0 left in bankroll
# Beezie is placing small blind: 1
# Beezie placed small blind: 8 left in bankroll
# delt Josh to Card("7", "Diamonds")
# delt Beezie to Card("3", "Clubs")
# delt Madi to Card("4", "Diamonds")
# delt Sophia to Card("3", "Spades")
# delt Josh to Card("8", "Spades")
# delt Beezie to Card("6", "Spades")
# delt Madi to Card("8", "Diamonds")
# delt Sophia to Card("Q", "Diamonds")
# Starting betting round
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 8
# Josh: FOLD
# Josh is folding: 8
# Josh folds
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 8
# Beezie: FOLD
# Beezie is folding: 8
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 183.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 181.0
# Action amount: 83
# Money on table: 2
# Cash into the pot: 81
# Cash into pot: 81
# Madi calling, raising, or matching by 83
# Madi still has: 100.0 in their bankroll
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 400.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 400.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Sophia calling, raising, or matching by 83
# Sophia still has: 317.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 183.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 100.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 100.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 400.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 317.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 317.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 183.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 100.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 100.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 400.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 317.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 317.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 183.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 100.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 100.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 400.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 317.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 317.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 183.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 100.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 100.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("4", "Diamonds"), Card("8", "Diamonds")]
# Madi makes a hand from: [Card("4", "Diamonds"), Card("8", "Diamonds"), Card("4", "Diamonds"), Card("8", "Diamonds"), Card("10", "Clubs"), Card("A", "Spades"), Card("8", "Clubs"), Card("10", "Spades"), Card("7", "Spades")]
# Madi presents hand: 8D, 8D, 10C, 8C, 10S
# Sophia is holding [Card("3", "Spades"), Card("Q", "Diamonds")]
# Sophia makes a hand from: [Card("3", "Spades"), Card("Q", "Diamonds"), Card("3", "Spades"), Card("Q", "Diamonds"), Card("10", "Clubs"), Card("A", "Spades"), Card("8", "Clubs"), Card("10", "Spades"), Card("7", "Spades")]
# Sophia presents hand: 3S, 3S, AS, 10S, 7S
# Madi is holding [Card("4", "Diamonds"), Card("8", "Diamonds"), Card("4", "Diamonds"), Card("8", "Diamonds"), Card("10", "Clubs"), Card("A", "Spades"), Card("8", "Clubs"), Card("10", "Spades"), Card("7", "Spades")]
# Madi presents hand: 8D, 8D, 10C, 8C, 10S
# Sophia is holding [Card("3", "Spades"), Card("Q", "Diamonds"), Card("3", "Spades"), Card("Q", "Diamonds"), Card("10", "Clubs"), Card("A", "Spades"), Card("8", "Clubs"), Card("10", "Spades"), Card("7", "Spades")]
# Sophia presents hand: 3S, 3S, AS, 10S, 7S
# Winning Hand: 8D, 8D, 10C, 8C, 10S
# ('FULL_HOUSE', '8', '10'): 8D, 8D, 10C, 8C, 10S
# ['Madi']
# Flop: [Card("10", "Clubs"), Card("A", "Spades"), Card("8", "Clubs")]
# Turn: Card("10", "Spades")
# River: Card("7", "Spades")
# Madi collects a $167.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 8)
# Player(Beezie, 8)
# Player(Madi, 267.0)
# Player(Sophia, 317.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > table.big_blind],
    table=table
).play()
# Out:
# Collecting blinds
# Sophia is placing big blind: 2
# Sophia placed big blind: 315.0 left in bankroll
# Madi is placing small blind: 1
# Madi placed small blind: 266.0 left in bankroll
# delt Josh to Card("9", "Clubs")
# delt Beezie to Card("A", "Hearts")
# delt Madi to Card("J", "Diamonds")
# delt Sophia to Card("6", "Spades")
# delt Josh to Card("3", "Clubs")
# delt Beezie to Card("7", "Hearts")
# delt Madi to Card("9", "Spades")
# delt Sophia to Card("7", "Clubs")
# Starting betting round
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 8
# Beezie: FOLD
# Beezie is folding: 8
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 267.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 266.0
# Action amount: 83
# Money on table: 1
# Cash into the pot: 82
# Cash into pot: 82
# Madi calling, raising, or matching by 83
# Madi still has: 184.0 in their bankroll
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 317.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 315.0
# Action amount: 83
# Money on table: 2
# Cash into the pot: 81
# Cash into pot: 81
# Sophia calling, raising, or matching by 83
# Sophia still has: 234.0 in their bankroll
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 8
# Josh: FOLD
# Josh is folding: 8
# Josh folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 267.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 184.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 184.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 317.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 234.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 234.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 267.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 184.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 184.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 317.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 234.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 234.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 267.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 184.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 184.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 317.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 234.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 234.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 267.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 184.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 184.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 317.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 234.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 234.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("J", "Diamonds"), Card("9", "Spades")]
# Madi makes a hand from: [Card("J", "Diamonds"), Card("9", "Spades"), Card("J", "Diamonds"), Card("9", "Spades"), Card("K", "Hearts"), Card("Q", "Clubs"), Card("A", "Clubs"), Card("6", "Hearts"), Card("J", "Clubs")]
# Madi presents hand: JD, 9S, JD, 9S, JC
# Sophia is holding [Card("6", "Spades"), Card("7", "Clubs")]
# Sophia makes a hand from: [Card("6", "Spades"), Card("7", "Clubs"), Card("6", "Spades"), Card("7", "Clubs"), Card("K", "Hearts"), Card("Q", "Clubs"), Card("A", "Clubs"), Card("6", "Hearts"), Card("J", "Clubs")]
# Sophia presents hand: 6S, 7C, 6S, 7C, 6H
# Madi is holding [Card("J", "Diamonds"), Card("9", "Spades"), Card("J", "Diamonds"), Card("9", "Spades"), Card("K", "Hearts"), Card("Q", "Clubs"), Card("A", "Clubs"), Card("6", "Hearts"), Card("J", "Clubs")]
# Madi presents hand: JD, 9S, JD, 9S, JC
# Sophia is holding [Card("6", "Spades"), Card("7", "Clubs"), Card("6", "Spades"), Card("7", "Clubs"), Card("K", "Hearts"), Card("Q", "Clubs"), Card("A", "Clubs"), Card("6", "Hearts"), Card("J", "Clubs")]
# Sophia presents hand: 6S, 7C, 6S, 7C, 6H
# Winning Hand: 6S, 7C, 6S, 7C, 6H
# ('FULL_HOUSE', '6', '7'): 6S, 7C, 6S, 7C, 6H
# ['Sophia']
# Flop: [Card("K", "Hearts"), Card("Q", "Clubs"), Card("A", "Clubs")]
# Turn: Card("6", "Hearts")
# River: Card("J", "Clubs")
# Sophia collects a $166.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 8)
# Player(Beezie, 8)
# Player(Madi, 184.0)
# Player(Sophia, 400.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > table.big_blind],
    table=table
).play()
# Out:
# Collecting blinds
# Josh is placing big blind: 2
# Josh placed big blind: 6 left in bankroll
# Sophia is placing small blind: 1
# Sophia placed small blind: 399.0 left in bankroll
# delt Josh to Card("9", "Spades")
# delt Beezie to Card("A", "Clubs")
# delt Madi to Card("2", "Hearts")
# delt Sophia to Card("8", "Clubs")
# delt Josh to Card("A", "Spades")
# delt Beezie to Card("8", "Diamonds")
# delt Madi to Card("5", "Hearts")
# delt Sophia to Card("7", "Clubs")
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 184.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 184.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Madi calling, raising, or matching by 83
# Madi still has: 101.0 in their bankroll
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 400.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 399.0
# Action amount: 83
# Money on table: 1
# Cash into the pot: 82
# Cash into pot: 82
# Sophia calling, raising, or matching by 83
# Sophia still has: 317.0 in their bankroll
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 6
# Josh: FOLD
# Josh is folding: 6
# Josh folds
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 8
# Beezie: FOLD
# Beezie is folding: 8
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 184.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 101.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 101.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 400.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 317.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 317.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 184.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 101.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 101.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 400.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 317.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 317.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 184.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 101.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 101.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 400.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 317.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 317.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 184.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 101.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 101.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 400.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 317.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 317.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("2", "Hearts"), Card("5", "Hearts")]
# Madi makes a hand from: [Card("2", "Hearts"), Card("5", "Hearts"), Card("2", "Hearts"), Card("5", "Hearts"), Card("9", "Hearts"), Card("K", "Clubs"), Card("4", "Diamonds"), Card("6", "Spades"), Card("5", "Spades")]
# Madi presents hand: 2H, 5H, 2H, 5H, 5S
# Sophia is holding [Card("8", "Clubs"), Card("7", "Clubs")]
# Sophia makes a hand from: [Card("8", "Clubs"), Card("7", "Clubs"), Card("8", "Clubs"), Card("7", "Clubs"), Card("9", "Hearts"), Card("K", "Clubs"), Card("4", "Diamonds"), Card("6", "Spades"), Card("5", "Spades")]
# Sophia presents hand: 8C, 7C, 8C, 7C, KC
# Madi is holding [Card("2", "Hearts"), Card("5", "Hearts"), Card("2", "Hearts"), Card("5", "Hearts"), Card("9", "Hearts"), Card("K", "Clubs"), Card("4", "Diamonds"), Card("6", "Spades"), Card("5", "Spades")]
# Madi presents hand: 2H, 5H, 2H, 5H, 5S
# Sophia is holding [Card("8", "Clubs"), Card("7", "Clubs"), Card("8", "Clubs"), Card("7", "Clubs"), Card("9", "Hearts"), Card("K", "Clubs"), Card("4", "Diamonds"), Card("6", "Spades"), Card("5", "Spades")]
# Sophia presents hand: 8C, 7C, 8C, 7C, KC
# Winning Hand: 2H, 5H, 2H, 5H, 5S
# ('FULL_HOUSE', '5', '2'): 2H, 5H, 2H, 5H, 5S
# ['Madi']
# Flop: [Card("9", "Hearts"), Card("K", "Clubs"), Card("4", "Diamonds")]
# Turn: Card("6", "Spades")
# River: Card("5", "Spades")
# Madi collects a $168.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 6)
# Player(Beezie, 8)
# Player(Madi, 269.0)
# Player(Sophia, 317.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > table.big_blind],
    table=table
).play()

for player in players:
    print(player)
# Out:
# Collecting blinds
# Beezie is placing big blind: 2
# Beezie placed big blind: 6 left in bankroll
# Josh is placing small blind: 1
# Josh placed small blind: 5 left in bankroll
# delt Josh to Card("5", "Clubs")
# delt Beezie to Card("Q", "Hearts")
# delt Madi to Card("9", "Spades")
# delt Sophia to Card("2", "Clubs")
# delt Josh to Card("6", "Clubs")
# delt Beezie to Card("8", "Clubs")
# delt Madi to Card("A", "Hearts")
# delt Sophia to Card("10", "Clubs")
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 317.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 317.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Sophia calling, raising, or matching by 83
# Sophia still has: 234.0 in their bankroll
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 5
# Josh: FOLD
# Josh is folding: 5
# Josh folds
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 6
# Beezie: FOLD
# Beezie is folding: 6
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 269.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 269.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Madi calling, raising, or matching by 83
# Madi still has: 186.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 317.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 234.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 234.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 269.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 186.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 186.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 317.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 234.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 234.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 269.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 186.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 186.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 317.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 234.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 234.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 269.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 186.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 186.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 317.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 234.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 234.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("9", "Spades"), Card("A", "Hearts")]
# Madi makes a hand from: [Card("9", "Spades"), Card("A", "Hearts"), Card("9", "Spades"), Card("A", "Hearts"), Card("9", "Clubs"), Card("8", "Spades"), Card("10", "Spades"), Card("Q", "Clubs"), Card("5", "Spades")]
# Madi presents hand: 9S, AH, 9S, AH, 9C
# Sophia is holding [Card("2", "Clubs"), Card("10", "Clubs")]
# Sophia makes a hand from: [Card("2", "Clubs"), Card("10", "Clubs"), Card("2", "Clubs"), Card("10", "Clubs"), Card("9", "Clubs"), Card("8", "Spades"), Card("10", "Spades"), Card("Q", "Clubs"), Card("5", "Spades")]
# Sophia presents hand: 2C, 10C, 2C, 10C, 10S
# Madi is holding [Card("9", "Spades"), Card("A", "Hearts"), Card("9", "Spades"), Card("A", "Hearts"), Card("9", "Clubs"), Card("8", "Spades"), Card("10", "Spades"), Card("Q", "Clubs"), Card("5", "Spades")]
# Madi presents hand: 9S, AH, 9S, AH, 9C
# Sophia is holding [Card("2", "Clubs"), Card("10", "Clubs"), Card("2", "Clubs"), Card("10", "Clubs"), Card("9", "Clubs"), Card("8", "Spades"), Card("10", "Spades"), Card("Q", "Clubs"), Card("5", "Spades")]
# Sophia presents hand: 2C, 10C, 2C, 10C, 10S
# Winning Hand: 2C, 10C, 2C, 10C, 10S
# ('FULL_HOUSE', '10', '2'): 2C, 10C, 2C, 10C, 10S
# ['Sophia']
# Flop: [Card("9", "Clubs"), Card("8", "Spades"), Card("10", "Spades")]
# Turn: Card("Q", "Clubs")
# River: Card("5", "Spades")
# Sophia collects a $169.0 pot
# Player(Josh, 5)
# Player(Beezie, 6)
# Player(Madi, 186.0)
# Player(Sophia, 403.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > table.big_blind],
    table=table
).play()
# Out:
# Collecting blinds
# Madi is placing big blind: 2
# Madi placed big blind: 184.0 left in bankroll
# Beezie is placing small blind: 1
# Beezie placed small blind: 5 left in bankroll
# delt Josh to Card("9", "Spades")
# delt Beezie to Card("9", "Hearts")
# delt Madi to Card("3", "Hearts")
# delt Sophia to Card("9", "Diamonds")
# delt Josh to Card("10", "Hearts")
# delt Beezie to Card("4", "Diamonds")
# delt Madi to Card("K", "Diamonds")
# delt Sophia to Card("Q", "Diamonds")
# Starting betting round
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 5
# Josh: FOLD
# Josh is folding: 5
# Josh folds
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 5
# Beezie: FOLD
# Beezie is folding: 5
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 186.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 184.0
# Action amount: 83
# Money on table: 2
# Cash into the pot: 81
# Cash into pot: 81
# Madi calling, raising, or matching by 83
# Madi still has: 103.0 in their bankroll
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 403.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 403.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Sophia calling, raising, or matching by 83
# Sophia still has: 320.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 186.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 103.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 103.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 403.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 320.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 320.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 186.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 103.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 103.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 403.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 320.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 320.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 186.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 103.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 103.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 403.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 320.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 320.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Round is called. Match or Fold to Madi
# Called - Active Player: Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 186.0
# Play - Madi: CALL
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 103.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 103.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("3", "Hearts"), Card("K", "Diamonds")]
# Madi makes a hand from: [Card("3", "Hearts"), Card("K", "Diamonds"), Card("3", "Hearts"), Card("K", "Diamonds"), Card("2", "Diamonds"), Card("4", "Spades"), Card("6", "Diamonds"), Card("8", "Spades"), Card("7", "Hearts")]
# Madi presents hand: 3H, KD, 3H, KD, 8S
# Sophia is holding [Card("9", "Diamonds"), Card("Q", "Diamonds")]
# Sophia makes a hand from: [Card("9", "Diamonds"), Card("Q", "Diamonds"), Card("9", "Diamonds"), Card("Q", "Diamonds"), Card("2", "Diamonds"), Card("4", "Spades"), Card("6", "Diamonds"), Card("8", "Spades"), Card("7", "Hearts")]
# Sophia presents hand: 9D, QD, 9D, QD, 6D
# Madi is holding [Card("3", "Hearts"), Card("K", "Diamonds"), Card("3", "Hearts"), Card("K", "Diamonds"), Card("2", "Diamonds"), Card("4", "Spades"), Card("6", "Diamonds"), Card("8", "Spades"), Card("7", "Hearts")]
# Madi presents hand: 3H, KD, 3H, KD, 8S
# Sophia is holding [Card("9", "Diamonds"), Card("Q", "Diamonds"), Card("9", "Diamonds"), Card("Q", "Diamonds"), Card("2", "Diamonds"), Card("4", "Spades"), Card("6", "Diamonds"), Card("8", "Spades"), Card("7", "Hearts")]
# Sophia presents hand: 9D, QD, 9D, QD, 6D
# Winning Hand: 9D, QD, 9D, QD, 6D
# ('FLUSH', Card("Q", "Diamonds")): 9D, QD, 9D, QD, 6D
# ['Sophia']
# Flop: [Card("2", "Diamonds"), Card("4", "Spades"), Card("6", "Diamonds")]
# Turn: Card("8", "Spades")
# River: Card("7", "Hearts")
# Sophia collects a $167.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 5)
# Player(Beezie, 5)
# Player(Madi, 103.0)
# Player(Sophia, 487.0)

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > table.big_blind],
    table=table
).play()
# Out:
# Collecting blinds
# Sophia is placing big blind: 2
# Sophia placed big blind: 485.0 left in bankroll
# Madi is placing small blind: 1
# Madi placed small blind: 102.0 left in bankroll
# delt Josh to Card("Q", "Spades")
# delt Beezie to Card("10", "Diamonds")
# delt Madi to Card("J", "Diamonds")
# delt Sophia to Card("9", "Spades")
# delt Josh to Card("10", "Spades")
# delt Beezie to Card("3", "Spades")
# delt Madi to Card("J", "Clubs")
# delt Sophia to Card("8", "Diamonds")
# Starting betting round
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 5
# Beezie: FOLD
# Beezie is folding: 5
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 103.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 102.0
# Action amount: 83
# Money on table: 1
# Cash into the pot: 82
# Cash into pot: 82
# Madi calling, raising, or matching by 83
# Madi still has: 20.0 in their bankroll
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 487.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 485.0
# Action amount: 83
# Money on table: 2
# Cash into the pot: 81
# Cash into pot: 81
# Sophia calling, raising, or matching by 83
# Sophia still has: 404.0 in their bankroll
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 5
# Josh: FOLD
# Josh is folding: 5
# Josh folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 103.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 20.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 20.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 487.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 404.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 404.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 103.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 20.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 20.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 487.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 404.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 404.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 103.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 20.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 20.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 487.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 404.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 404.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 103.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 20.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 20.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 487.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 404.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 404.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("J", "Diamonds"), Card("J", "Clubs")]
# Madi makes a hand from: [Card("J", "Diamonds"), Card("J", "Clubs"), Card("J", "Diamonds"), Card("J", "Clubs"), Card("8", "Hearts"), Card("9", "Diamonds"), Card("K", "Spades"), Card("Q", "Clubs"), Card("4", "Clubs")]
# Madi presents hand: JD, JC, JD, JC, KS
# Sophia is holding [Card("9", "Spades"), Card("8", "Diamonds")]
# Sophia makes a hand from: [Card("9", "Spades"), Card("8", "Diamonds"), Card("9", "Spades"), Card("8", "Diamonds"), Card("8", "Hearts"), Card("9", "Diamonds"), Card("K", "Spades"), Card("Q", "Clubs"), Card("4", "Clubs")]
# Sophia presents hand: 8D, 9S, 8D, 8H, 9D
# Madi is holding [Card("J", "Diamonds"), Card("J", "Clubs"), Card("J", "Diamonds"), Card("J", "Clubs"), Card("8", "Hearts"), Card("9", "Diamonds"), Card("K", "Spades"), Card("Q", "Clubs"), Card("4", "Clubs")]
# Madi presents hand: JD, JC, JD, JC, KS
# Sophia is holding [Card("9", "Spades"), Card("8", "Diamonds"), Card("9", "Spades"), Card("8", "Diamonds"), Card("8", "Hearts"), Card("9", "Diamonds"), Card("K", "Spades"), Card("Q", "Clubs"), Card("4", "Clubs")]
# Sophia presents hand: 8D, 9S, 8D, 8H, 9D
# Winning Hand: JD, JC, JD, JC, KS
# ('FOUR_OF_A_KIND', 'J'): JD, JC, JD, JC, KS
# ['Madi']
# Flop: [Card("8", "Hearts"), Card("9", "Diamonds"), Card("K", "Spades")]
# Turn: Card("Q", "Clubs")
# River: Card("4", "Clubs")
# Madi collects a $166.0 pot

# %%
players, table = HoldemRound(
    players=[player for player in players if player.bankroll > table.big_blind],
    table=table
).play()
# Out:
# Collecting blinds
# Josh is placing big blind: 2
# Josh placed big blind: 3 left in bankroll
# Sophia is placing small blind: 1
# Sophia placed small blind: 403.0 left in bankroll
# delt Josh to Card("10", "Clubs")
# delt Beezie to Card("Q", "Clubs")
# delt Madi to Card("8", "Hearts")
# delt Sophia to Card("4", "Hearts")
# delt Josh to Card("6", "Hearts")
# delt Beezie to Card("2", "Spades")
# delt Madi to Card("7", "Diamonds")
# delt Sophia to Card("2", "Diamonds")
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 186.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 186.0
# Action amount: 83
# Money on table: 0
# Cash into the pot: 83
# Cash into pot: 83
# Madi calling, raising, or matching by 83
# Madi still has: 103.0 in their bankroll
# The bet is 83 to Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 404.0
# Play - Sophia: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 403.0
# Action amount: 83
# Money on table: 1
# Cash into the pot: 82
# Cash into pot: 82
# Sophia calling, raising, or matching by 83
# Sophia still has: 321.0 in their bankroll
# The bet is 83 to Josh
# Play - Josh: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Josh: FOLD
# Josh: 3
# Josh: FOLD
# Josh is folding: 3
# Josh folds
# The bet is 83 to Beezie
# Play - Beezie: FOLD
# Got action: Action(FOLD, None)
# handling action: Action(FOLD, None)
# Processing Action - Beezie: FOLD
# Beezie: 5
# Beezie: FOLD
# Beezie is folding: 5
# Beezie folds
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 186.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 103.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 103.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 404.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 321.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 321.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 186.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 103.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 103.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 404.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 321.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 321.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 186.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 103.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 103.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 404.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 321.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 321.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Starting betting round
# The bet is 83 to Madi
# Madi sees the bet is at: 83
# Madi has a max bet of 186.0
# Play - Madi: CALL
# Got action: Action(CALL, 83)
# handling action: Action(CALL, 83)
# Processing Action - Madi: CALL
# Madi: 103.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Madi calling, raising, or matching by 83
# Madi still has: 103.0 in their bankroll
# Madi calls, setting holdem_round.is_called = True
# Betting is called...settling up with  remaining players
# Players still in: ['Madi', 'Sophia']
# Round is called. Match or Fold to Sophia
# Called - Active Player: Sophia
# Sophia sees the bet is at: 83
# Sophia has a max bet of 404.0
# Play - Sophia: CALL
# handling action: Action(CALL, 83)
# Processing Action - Sophia: CALL
# Sophia: 321.0
# Action amount: 83
# Money on table: 83
# Cash into the pot: 0
# Cash into pot: 0
# Sophia calling, raising, or matching by 83
# Sophia still has: 321.0 in their bankroll
# Sophia calls, setting holdem_round.is_called = True
# Round is called. Match or Fold to Josh
# Round is called. Match or Fold to Beezie
# Betting round is complete
# Players still in: ['Madi', 'Sophia']
# Madi is holding [Card("8", "Hearts"), Card("7", "Diamonds")]
# Madi makes a hand from: [Card("8", "Hearts"), Card("7", "Diamonds"), Card("8", "Hearts"), Card("7", "Diamonds"), Card("K", "Clubs"), Card("K", "Diamonds"), Card("J", "Spades"), Card("9", "Diamonds"), Card("9", "Spades")]
# Madi presents hand: KC, KD, JS, 9D, 9S
# Sophia is holding [Card("4", "Hearts"), Card("2", "Diamonds")]
# Sophia makes a hand from: [Card("4", "Hearts"), Card("2", "Diamonds"), Card("4", "Hearts"), Card("2", "Diamonds"), Card("K", "Clubs"), Card("K", "Diamonds"), Card("J", "Spades"), Card("9", "Diamonds"), Card("9", "Spades")]
# Sophia presents hand: KC, KD, JS, 9D, 9S
# Madi is holding [Card("8", "Hearts"), Card("7", "Diamonds"), Card("8", "Hearts"), Card("7", "Diamonds"), Card("K", "Clubs"), Card("K", "Diamonds"), Card("J", "Spades"), Card("9", "Diamonds"), Card("9", "Spades")]
# Madi presents hand: KC, KD, JS, 9D, 9S
# Sophia is holding [Card("4", "Hearts"), Card("2", "Diamonds"), Card("4", "Hearts"), Card("2", "Diamonds"), Card("K", "Clubs"), Card("K", "Diamonds"), Card("J", "Spades"), Card("9", "Diamonds"), Card("9", "Spades")]
# Sophia presents hand: KC, KD, JS, 9D, 9S
# Winning Hand: KC, KD, JS, 9D, 9S
# ('TWO_PAIR', ['9', 'K']): KC, KD, JS, 9D, 9S
# ['Madi', 'Sophia']
# Flop: [Card("K", "Clubs"), Card("K", "Diamonds"), Card("J", "Spades")]
# Turn: Card("9", "Diamonds")
# River: Card("9", "Spades")
# Multiple Winners...
#     Winner: Madi
# Madi hole: [Card("8", "Hearts"), Card("7", "Diamonds"), Card("8", "Hearts"), Card("7", "Diamonds"), Card("K", "Clubs"), Card("K", "Diamonds"), Card("J", "Spades"), Card("9", "Diamonds"), Card("9", "Spades")]
# Multiple Winners...
#     Winner: Sophia
# Sophia hole: [Card("4", "Hearts"), Card("2", "Diamonds"), Card("4", "Hearts"), Card("2", "Diamonds"), Card("K", "Clubs"), Card("K", "Diamonds"), Card("J", "Spades"), Card("9", "Diamonds"), Card("9", "Spades")]
# Madi: KC, KD, JS, 9D, 9S
# Sophia: KC, KD, JS, 9D, 9S
# Madi collects a $84.0 pot
# Sophia collects a $84.0 pot

# %%
for player in players:
    print(player)
# Out:
# Player(Josh, 3)
# Player(Beezie, 5)
# Player(Madi, 187.0)
# Player(Sophia, 405.0)
